# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv('SMSSpamCollection.txt',sep='\t', header=None)
dataset.head()
# Out:
#       0                                                  1
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
dataset.columns = ["label", "content"]
dataset.head(5)
# Out:
#   label                                            content
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
import gensim

# %% [markdown]
# In Gensim, simple_preprocess() is a utility function used primarily for tokenization and lowercasing of text. It is commonly used to preprocess text data before training models like Word2Vec or Doc2Vec.

# %%
dataset['content_list'] = dataset['content'].apply(lambda x: gensim.utils.simple_preprocess(x))
dataset.head()
# Out:
#   label                                            content  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                         content_list
# 0  [go, until, jurong, point, crazy, available, o...
# 1                        [ok, lar, joking, wif, oni]
# 2  [free, entry, in, wkly, comp, to, win, fa, cup...
# 3     [dun, say, so, early, hor, already, then, say]
# 4  [nah, don, think, he, goes, to, usf, he, lives...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset['content_list'],
                                                    dataset['label'], test_size=0.2)
X_train = X_train.reset_index(drop = True)
X_test = X_test.reset_index(drop = True)

# %%
X_train
# Out:
# 0       [oops, sorry, just, to, check, that, you, don,...
# 1                   [ofcourse, also, upload, some, songs]
# 2                         [think, he, is, waste, for, rr]
# 3                           [sleeping, nt, feeling, well]
# 4       [naughty, little, thought, its, better, to, fl...
#                               ...
# 4452    [thanks, for, being, there, for, me, just, to,...
# 4453    [no, worries, hope, photo, shoot, went, well, ...
# 4454    [hi, ibh, customer, loyalty, offer, the, new, ...
# 4455    [hope, you, are, having, good, week, just, che...
# 4456    [exactly, anyways, how, far, is, jide, her, to...
# Name: content_list, Length: 4457, dtype: object

# %%
w2v_model = gensim.models.Word2Vec(X_train,
                                   vector_size=100,
                                   window=5,
                                   min_count=1)

# %%
words = set(w2v_model.wv.index_to_key)

# %%
w2v_model.wv['sms']
# Out:
# array([-0.15142632,  0.21867478,  0.05885001,  0.12663871,  0.15928213,
#        -0.53906465,  0.07473314,  0.6517776 , -0.3603537 , -0.12470852,
#        -0.19115774, -0.4507057 , -0.02539421,  0.18959759,  0.12222846,
#        -0.29978102,  0.10197094, -0.53295   , -0.06405067, -0.6666478 ,
#         0.14740033,  0.07682581,  0.17461619, -0.16603442, -0.086747  ,
#        -0.00962673, -0.272106  , -0.16067363, -0.36208418,  0.00834167,
#         0.36958823, -0.04969084,  0.07407066, -0.35968542, -0.15670985,
#         0.31081018, -0.04028242, -0.27017716, -0.26608014, -0.4661021 ,
#        -0.02053764, -0.35705453, -0.13470306,  0.10903416,  0.2841492 ,
#        -0.04548687, -0.25264126, -0.04296437,  0.07542148,  0.26872188,
#         0.20428345, -0.14496394, -0.13589919, -0.04947977, -0.17465486,
#         0.05001741,  0.22373298, -0.00931252, -0.2620245 ,  0.11640106,
#         0.0711076 ,  0.1306734 , -0.00418927,  0.05813746, -0.2940321 ,
#         0.41918877,  0.19666962,  0.2583003 , -0.45738348,  0.5352222 ,
#        -0.12279661,  0.1468662 ,  0.3100743 , -0.07569375,  0.36226222,
#         0.12154821, -0.05360797,  0.03620815, -0.28959325,  0.08191777,
#        -0.22644833,  0.08992118, -0.3289602 ,  0.35445407, -0.15676026,
#        -0.11260937,  0.04338782,  0.36602873,  0.5154012 ,  0.24510586,
#         0.53490806,  0.19282052,  0.03141135,  0.11525937,  0.5610174 ,
#         0.30891535,  0.11997704, -0.27800626,  0.07160981, -0.0840527 ],
#       dtype=float32)

# %%
x_train = X_train.tolist()
x_train
# Out:
# [['oops',
#   'sorry',
#   'just',
#   'to',
#   'check',
#   'that',
#   'you',
#   'don',
#   'mind',
#   'picking',
#   'me',
#   'up',
#   'tomo',
#   'at',
#   'half',
#   'eight',
#   'from',
#   'station',
#   'would',
#   'that',
#   'be',
#   'ok'],
#  ['ofcourse', 'also', 'upload', 'some', 'songs'],
#  ['think', 'he', 'is', 'waste', 'for', 'rr'],
#  ['sleeping', 'nt', 'feeling', 'well'],
#  ['naughty',
#   'little',
#   'thought',
#   'its',
#   'better',
#   'to',
#   'flirt',
#   'flirt',
#   'flirt',
#   'rather',
#   'than',
#   'loving',
#   'someone',
#   'gettin',
#   'hurt',
#   'hurt',
#   'hurt',
#   'gud',
#   'nyt'],
#  ['no', 'yes', 'please', 'been', 'swimming'],
#  ['yeah', 'confirmed', 'for', 'you', 'staying', 'at', 'that', 'weekend'],
#  ['hello',
#   'how',
#   'doing',
#   'what',
#   'been',
#   'up',
#   'when',
#   'will',
#   'moving',
#   'out',
#   'of',
#   'the',
#   'flat',
#   'cos',
#   'will',
#   'need',
#   'to',
#   'arrange',
#   'to',
#   'pick',
#   'up',
#   'the',
#   'lamp',
#   'etc',
#   'take',
#   'care',
#   'hello',
#   'caroline'],
#  ['how',
#   'are',
#   'you',
#   'doing',
#   'how',
#   'the',
#   'queen',
#   'are',
#   'you',
#   'going',
#   'for',
#   'the',
#   'royal',
#   'wedding'],
#  ['fine', 'am', 'simply', 'sitting'],
#  ['networks',
#   'allow',
#   'companies',
#   'to',
#   'bill',
#   'for',
#   'sms',
#   'so',
#   'they',
#   'are',
#   'responsible',
#   'for',
#   'their',
#   'suppliers',
#   'just',
#   'as',
#   'shop',
#   'has',
#   'to',
#   'give',
#   'guarantee',
#   'on',
#   'what',
#   'they',
#   'sell'],
#  ['ve', 'reached', 'home', 'finally'],
#  ['can', 'that', 'happen', 'tonight'],
#  ['please',
#   'da',
#   'call',
#   'me',
#   'any',
#   'mistake',
#   'from',
#   'my',
#   'side',
#   'sorry',
#   'da',
#   'pls',
#   'da',
#   'goto',
#   'doctor'],
#  ['xmas',
#   'new',
#   'years',
#   'eve',
#   'tickets',
#   'are',
#   'now',
#   'on',
#   'sale',
#   'from',
#   'the',
#   'club',
#   'during',
#   'the',
#   'day',
#   'from',
#   'am',
#   'till',
#   'pm',
#   'and',
#   'on',
#   'thurs',
#   'fri',
#   'sat',
#   'night',
#   'this',
#   'week',
#   'they',
#   're',
#   'selling',
#   'fast'],
#  ['lol', 'knew', 'that', 'saw', 'him', 'in', 'the', 'dollar', 'store'],
#  ['are', 'you', 'still', 'playing', 'with', 'gautham'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['forwarded',
#   'from',
#   'please',
#   'call',
#   'immediately',
#   'as',
#   'there',
#   'is',
#   'an',
#   'urgent',
#   'message',
#   'waiting',
#   'for',
#   'you'],
#  ['ok', 'then', 'we', 'meeting', 'later'],
#  ['hurt',
#   'me',
#   'tease',
#   'me',
#   'make',
#   'me',
#   'cry',
#   'but',
#   'in',
#   'the',
#   'end',
#   'of',
#   'my',
#   'life',
#   'when',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'on',
#   'my',
#   'grave',
#   'and',
#   'say',
#   'stupid',
#   'miss',
#   'have',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pounds',
#   'of',
#   'genuine',
#   'hmv',
#   'vouchers',
#   'to',
#   'be',
#   'won',
#   'just',
#   'answer',
#   'easy',
#   'questions',
#   'play',
#   'now',
#   'send',
#   'hmv',
#   'to',
#   'more',
#   'info',
#   'www',
#   'percent',
#   'real',
#   'com'],
#  ['can', 'dunno', 'wat', 'to', 'get', 'her'],
#  ['sorry', 'that', 'was', 'my', 'uncle', 'll', 'keep', 'in', 'touch'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'out',
#   'tomo',
#   'then',
#   'return',
#   'it',
#   'immediately',
#   'or',
#   'something'],
#  ['arun', 'can', 'transfr', 'me', 'amt'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'todays',
#   'draw',
#   'shows',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hrs',
#   'only'],
#  ['hi', 'dude', 'hw', 'da', 'realy', 'mising', 'today'],
#  ['yar',
#   'lor',
#   'keep',
#   'raining',
#   'non',
#   'stop',
#   'or',
#   'wan',
#   'go',
#   'elsewhere'],
#  ['hello',
#   'handsome',
#   'are',
#   'you',
#   'finding',
#   'that',
#   'job',
#   'not',
#   'being',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'that',
#   'net',
#   'for',
#   'mummy',
#   'where',
#   'my',
#   'boytoy',
#   'now',
#   'does',
#   'he',
#   'miss',
#   'me'],
#  ['no', 'll', 'meet', 'you', 'in', 'the', 'library'],
#  ['poor', 'girl', 'can', 'go', 'one', 'day', 'lmao'],
#  ['goodmorning', 'today', 'am', 'late', 'for', 'lt', 'gt', 'min'],
#  ['this',
#   'pen',
#   'thing',
#   'is',
#   'beyond',
#   'joke',
#   'wont',
#   'biro',
#   'do',
#   'don',
#   'do',
#   'masters',
#   'as',
#   'can',
#   'do',
#   'this',
#   'ever',
#   'again'],
#  ['congrats',
#   'mobile',
#   'videophones',
#   'yours',
#   'call',
#   'now',
#   'videochat',
#   'wid',
#   'ur',
#   'mates',
#   'play',
#   'java',
#   'games',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl',
#   'bx',
#   'ip',
#   'we'],
#  ['spoons', 'it', 'is', 'then', 'okay'],
#  ['thanx', 'lot'],
#  ['now',
#   'only',
#   'reached',
#   'home',
#   'am',
#   'very',
#   'tired',
#   'now',
#   'will',
#   'come',
#   'tomorro'],
#  ['your',
#   'weekly',
#   'cool',
#   'mob',
#   'tones',
#   'are',
#   'ready',
#   'to',
#   'download',
#   'this',
#   'weeks',
#   'new',
#   'tones',
#   'include',
#   'crazy',
#   'frog',
#   'axel',
#   'akon',
#   'lonely',
#   'black',
#   'eyed',
#   'dont',
#   'more',
#   'info',
#   'in'],
#  ['tessy',
#   'pls',
#   'do',
#   'me',
#   'favor',
#   'pls',
#   'convey',
#   'my',
#   'birthday',
#   'wishes',
#   'to',
#   'nimya',
#   'pls',
#   'dnt',
#   'forget',
#   'it',
#   'today',
#   'is',
#   'her',
#   'birthday',
#   'shijas'],
#  ['haha',
#   'good',
#   'to',
#   'hear',
#   'officially',
#   'paid',
#   'and',
#   'on',
#   'the',
#   'market',
#   'for',
#   'an',
#   'th'],
#  ['sorry',
#   'brah',
#   'just',
#   'finished',
#   'the',
#   'last',
#   'of',
#   'my',
#   'exams',
#   'what',
#   'up'],
#  ['always',
#   'chat',
#   'with',
#   'you',
#   'in',
#   'fact',
#   'need',
#   'money',
#   'can',
#   'you',
#   'raise',
#   'me'],
#  ['romcapspam',
#   'everyone',
#   'around',
#   'should',
#   'be',
#   'responding',
#   'well',
#   'to',
#   'your',
#   'presence',
#   'since',
#   'you',
#   'are',
#   'so',
#   'warm',
#   'and',
#   'outgoing',
#   'you',
#   'are',
#   'bringing',
#   'in',
#   'real',
#   'breath',
#   'of',
#   'sunshine'],
#  ['don',
#   'know',
#   'and',
#   'don',
#   'know',
#   'me',
#   'send',
#   'chat',
#   'to',
#   'now',
#   'and',
#   'let',
#   'find',
#   'each',
#   'other',
#   'only',
#   'msg',
#   'rcvd',
#   'hg',
#   'suite',
#   'lands',
#   'row',
#   'hl',
#   'ldn',
#   'years',
#   'or',
#   'over'],
#  ['ya',
#   'but',
#   'it',
#   'cant',
#   'display',
#   'internal',
#   'subs',
#   'so',
#   'gotta',
#   'extract',
#   'them'],
#  ['ill',
#   'drink',
#   'pa',
#   'then',
#   'what',
#   'doing',
#   'need',
#   'srs',
#   'model',
#   'pls',
#   'send',
#   'it',
#   'to',
#   'my',
#   'mail',
#   'id',
#   'pa'],
#  ['moji',
#   'just',
#   'informed',
#   'me',
#   'that',
#   'you',
#   'saved',
#   'our',
#   'lives',
#   'thanks'],
#  ['ok'],
#  ['have', 'you', 'always', 'been', 'saying', 'welp'],
#  ['watching',
#   'cartoon',
#   'listening',
#   'music',
#   'amp',
#   'at',
#   'eve',
#   'had',
#   'to',
#   'go',
#   'temple',
#   'amp',
#   'church',
#   'what',
#   'about'],
#  ['hi',
#   'babe',
#   'its',
#   'jordan',
#   'how',
#   'im',
#   'home',
#   'from',
#   'abroad',
#   'and',
#   'lonely',
#   'text',
#   'me',
#   'back',
#   'if',
#   'wanna',
#   'chat',
#   'xxsp',
#   'visionsms',
#   'com',
#   'text',
#   'stop',
#   'to',
#   'stopcost'],
#  ['dont', 'know', 'oh', 'hopefully', 'this', 'month'],
#  ['those', 'were', 'my', 'exact', 'intentions'],
#  ['otherwise', 'had', 'part', 'time', 'job', 'na', 'tuition'],
#  ['do', 'you', 'know', 'where', 'my', 'lab', 'goggles', 'went'],
#  ['yes', 'thought', 'so', 'thanks'],
#  ['you',
#   'know',
#   'there',
#   'is',
#   'shall',
#   'speak',
#   'to',
#   'you',
#   'in',
#   'lt',
#   'gt',
#   'minutes',
#   'then'],
#  ['finish', 'liao'],
#  ['lol',
#   'no',
#   'just',
#   'trying',
#   'to',
#   'make',
#   'your',
#   'day',
#   'little',
#   'more',
#   'interesting'],
#  ['will', 'be', 'september', 'by', 'then'],
#  ['omg',
#   'joanna',
#   'is',
#   'freaking',
#   'me',
#   'out',
#   'she',
#   'looked',
#   'thru',
#   'all',
#   'my',
#   'friends',
#   'to',
#   'find',
#   'photos',
#   'of',
#   'me',
#   'and',
#   'then',
#   'she',
#   'asking',
#   'about',
#   'stuff',
#   'on',
#   'my',
#   'myspace',
#   'which',
#   'haven',
#   'even',
#   'logged',
#   'on',
#   'in',
#   'like',
#   'year'],
#  ['kick',
#   'off',
#   'new',
#   'season',
#   'with',
#   'wks',
#   'free',
#   'goals',
#   'news',
#   'to',
#   'ur',
#   'mobile',
#   'txt',
#   'ur',
#   'club',
#   'name',
#   'to',
#   'eg',
#   'villa',
#   'to'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'todays',
#   'draw',
#   'shows',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hrs',
#   'only'],
#  ['me', 'fine', 'absolutly', 'fine'],
#  ['good', 'morning', 'plz', 'call', 'me', 'sir'],
#  ['sorry',
#   'now',
#   'then',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'so',
#   'poor',
#   'thing',
#   'but',
#   'only',
#   'one',
#   'night',
#   'tmr',
#   'll',
#   'have',
#   'brand',
#   'new',
#   'room',
#   'sleep',
#   'in'],
#  ['huh',
#   'means',
#   'computational',
#   'science',
#   'they',
#   'like',
#   'dat',
#   'one',
#   'push',
#   'here',
#   'there'],
#  ['no',
#   'meant',
#   'the',
#   'calculation',
#   'is',
#   'the',
#   'same',
#   'that',
#   'lt',
#   'gt',
#   'units',
#   'at',
#   'lt',
#   'gt',
#   'this',
#   'school',
#   'is',
#   'really',
#   'expensive',
#   'have',
#   'you',
#   'started',
#   'practicing',
#   'your',
#   'accent',
#   'because',
#   'its',
#   'important',
#   'and',
#   'have',
#   'you',
#   'decided',
#   'if',
#   'you',
#   'are',
#   'doing',
#   'years',
#   'of',
#   'dental',
#   'school',
#   'or',
#   'if',
#   'you',
#   'll',
#   'just',
#   'do',
#   'the',
#   'nmde',
#   'exam'],
#  ['love', 'working', 'from', 'home'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'and', 'deepak', 'min', 'hold'],
#  ['only', 'send', 'me', 'the', 'contents', 'page'],
#  ['shopping', 'eh', 'ger', 'toking', 'abt', 'syd', 'leh', 'haha'],
#  ['and',
#   'whenever',
#   'you',
#   'and',
#   'see',
#   'we',
#   'can',
#   'still',
#   'hook',
#   'up',
#   'too'],
#  ['will',
#   'be',
#   'gentle',
#   'baby',
#   'soon',
#   'you',
#   'will',
#   'be',
#   'taking',
#   'all',
#   'lt',
#   'gt',
#   'inches',
#   'deep',
#   'inside',
#   'your',
#   'tight',
#   'pussy'],
#  ['dont',
#   'forget',
#   'you',
#   'can',
#   'place',
#   'as',
#   'many',
#   'free',
#   'requests',
#   'with',
#   'stchoice',
#   'co',
#   'uk',
#   'as',
#   'you',
#   'wish',
#   'for',
#   'more',
#   'information',
#   'call'],
#  ['ya', 'tel', 'wats', 'ur', 'problem'],
#  ['reminder',
#   'from',
#   'to',
#   'get',
#   'pounds',
#   'free',
#   'call',
#   'credit',
#   'and',
#   'details',
#   'of',
#   'great',
#   'offers',
#   'pls',
#   'reply',
#   'this',
#   'text',
#   'with',
#   'your',
#   'valid',
#   'name',
#   'house',
#   'no',
#   'and',
#   'postcode'],
#  ['dont', 'talk', 'to', 'him', 'ever', 'ok', 'its', 'my', 'word'],
#  ['hello',
#   'we',
#   'need',
#   'some',
#   'posh',
#   'birds',
#   'and',
#   'chaps',
#   'to',
#   'user',
#   'trial',
#   'prods',
#   'for',
#   'champneys',
#   'can',
#   'put',
#   'you',
#   'down',
#   'need',
#   'your',
#   'address',
#   'and',
#   'dob',
#   'asap',
#   'ta'],
#  ['lol',
#   'well',
#   'quality',
#   'aint',
#   'bad',
#   'at',
#   'all',
#   'so',
#   'aint',
#   'complaining'],
#  ['good',
#   'evening',
#   'sir',
#   'al',
#   'salam',
#   'wahleykkum',
#   'sharing',
#   'happy',
#   'news',
#   'by',
#   'the',
#   'grace',
#   'of',
#   'god',
#   'got',
#   'an',
#   'offer',
#   'from',
#   'tayseer',
#   'tissco',
#   'and',
#   'joined',
#   'hope',
#   'you',
#   'are',
#   'fine',
#   'inshah',
#   'allah',
#   'meet',
#   'you',
#   'sometime',
#   'rakhesh',
#   'visitor',
#   'from',
#   'india'],
#  ['am',
#   'in',
#   'escape',
#   'theatre',
#   'now',
#   'going',
#   'to',
#   'watch',
#   'kavalan',
#   'in',
#   'few',
#   'minutes'],
#  ['ok', 'coming', 'home', 'now'],
#  ['the',
#   'lt',
#   'gt',
#   'that',
#   'saw',
#   'few',
#   'days',
#   'ago',
#   'the',
#   'guy',
#   'wants',
#   'sell',
#   'wifi',
#   'only',
#   'for',
#   'lt',
#   'gt',
#   'and',
#   'with',
#   'for',
#   'lt',
#   'gt',
#   'that',
#   'why',
#   'blanked',
#   'him'],
#  ['men',
#   'always',
#   'needs',
#   'beautiful',
#   'intelligent',
#   'caring',
#   'loving',
#   'adjustable',
#   'cooperative',
#   'wife',
#   'but',
#   'the',
#   'law',
#   'allows',
#   'only',
#   'one',
#   'wife'],
#  ['send', 'to', 'someone', 'else'],
#  ['no', 'no', 'will', 'check', 'all', 'rooms', 'befor', 'activities'],
#  ['that', 'said', 'can', 'you', 'text', 'him', 'one', 'more', 'time'],
#  ['summers',
#   'finally',
#   'here',
#   'fancy',
#   'chat',
#   'or',
#   'flirt',
#   'with',
#   'sexy',
#   'singles',
#   'in',
#   'yr',
#   'area',
#   'to',
#   'get',
#   'matched',
#   'up',
#   'just',
#   'reply',
#   'summer',
#   'now',
#   'free',
#   'join',
#   'optout',
#   'txt',
#   'stop',
#   'help'],
#  ['should', 'head', 'straight', 'there', 'or', 'what'],
#  ['hi',
#   'petey',
#   'noi',
#   'ok',
#   'just',
#   'wanted',
#   'chat',
#   'coz',
#   'avent',
#   'spoken',
#   'long',
#   'time',
#   'hope',
#   'ur',
#   'doin',
#   'alrite',
#   'have',
#   'good',
#   'nit',
#   'at',
#   'js',
#   'love',
#   'ya',
#   'am'],
#  ['double',
#   'eviction',
#   'this',
#   'week',
#   'spiral',
#   'and',
#   'michael',
#   'and',
#   'good',
#   'riddance',
#   'to',
#   'them'],
#  ['nights', 'we', 'nt', 'staying', 'at', 'port', 'step', 'liao', 'too', 'ex'],
#  ['wait', 'lt', 'gt', 'min'],
#  ['delhi', 'and', 'chennai', 'still', 'silent'],
#  ['its',
#   'going',
#   'good',
#   'no',
#   'problem',
#   'but',
#   'still',
#   'need',
#   'little',
#   'experience',
#   'to',
#   'understand',
#   'american',
#   'customer',
#   'voice'],
#  ['when', 'are', 'you', 'going', 'to', 'ride', 'your', 'bike'],
#  ['gonna', 'rip', 'out', 'my', 'uterus'],
#  ['hi', 'good', 'mornin', 'thanku', 'wish', 'same'],
#  ['ujhhhhhhh',
#   'computer',
#   'shipped',
#   'out',
#   'with',
#   'address',
#   'to',
#   'sandiago',
#   'and',
#   'parantella',
#   'lane',
#   'wtf',
#   'poop'],
#  ['did', 'you', 'try', 'making', 'another', 'butt'],
#  ['come', 'aftr', 'lt', 'decimal', 'gt', 'now', 'cleaning', 'the', 'house'],
#  ['loan',
#   'for',
#   'any',
#   'purpose',
#   'homeowners',
#   'tenants',
#   'welcome',
#   'have',
#   'you',
#   'been',
#   'previously',
#   'refused',
#   'we',
#   'can',
#   'still',
#   'help',
#   'call',
#   'free',
#   'or',
#   'text',
#   'back',
#   'help'],
#  ['at',
#   'bruce',
#   'amp',
#   'fowler',
#   'now',
#   'but',
#   'in',
#   'my',
#   'mom',
#   'car',
#   'so',
#   'can',
#   'park',
#   'long',
#   'story'],
#  ['sure',
#   'if',
#   'get',
#   'an',
#   'acknowledgement',
#   'from',
#   'you',
#   'that',
#   'it',
#   'astoundingly',
#   'tactless',
#   'and',
#   'generally',
#   'faggy',
#   'to',
#   'demand',
#   'blood',
#   'oath',
#   'fo'],
#  ['sometimes',
#   'we',
#   'put',
#   'walls',
#   'around',
#   'our',
#   'hearts',
#   'not',
#   'just',
#   'to',
#   'be',
#   'safe',
#   'from',
#   'getting',
#   'hurt',
#   'but',
#   'to',
#   'find',
#   'out',
#   'who',
#   'cares',
#   'enough',
#   'to',
#   'break',
#   'the',
#   'walls',
#   'amp',
#   'get',
#   'closer',
#   'goodnoon'],
#  ['yeah',
#   'work',
#   'is',
#   'fine',
#   'started',
#   'last',
#   'week',
#   'all',
#   'the',
#   'same',
#   'stuff',
#   'as',
#   'before',
#   'dull',
#   'but',
#   'easy',
#   'and',
#   'guys',
#   'are',
#   'fun'],
#  ['need', 'details', 'about', 'that', 'online', 'job'],
#  ['gran', 'onlyfound', 'out', 'afew', 'days', 'ago', 'cusoon', 'honi'],
#  ['is',
#   'it',
#   'your',
#   'yahoo',
#   'boys',
#   'that',
#   'bring',
#   'in',
#   'the',
#   'perf',
#   'or',
#   'legal'],
#  ['did',
#   'he',
#   'say',
#   'how',
#   'fantastic',
#   'am',
#   'by',
#   'any',
#   'chance',
#   'or',
#   'anything',
#   'need',
#   'bigger',
#   'life',
#   'lift',
#   'as',
#   'losing',
#   'the',
#   'will',
#   'live',
#   'do',
#   'you',
#   'think',
#   'would',
#   'be',
#   'the',
#   'first',
#   'person',
#   'die',
#   'from'],
#  ['hi',
#   'im',
#   'having',
#   'the',
#   'most',
#   'relaxing',
#   'time',
#   'ever',
#   'we',
#   'have',
#   'to',
#   'get',
#   'up',
#   'at',
#   'am',
#   'every',
#   'day',
#   'was',
#   'the',
#   'party',
#   'good',
#   'the',
#   'other',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'at',
#   'ish'],
#  ['love',
#   'you',
#   'you',
#   'know',
#   'can',
#   'you',
#   'feel',
#   'it',
#   'does',
#   'it',
#   'make',
#   'your',
#   'belly',
#   'warm',
#   'wish',
#   'it',
#   'does',
#   'my',
#   'love',
#   'shall',
#   'meet',
#   'you',
#   'in',
#   'your',
#   'dreams',
#   'ahmad',
#   'adoring',
#   'kiss'],
#  ['nope', 'meanwhile', 'she', 'talk', 'say', 'make', 'greet', 'you'],
#  ['call',
#   'to',
#   'use',
#   'ur',
#   'mins',
#   'calls',
#   'cast',
#   'min',
#   'mob',
#   'vary',
#   'service',
#   'provided',
#   'by',
#   'aom',
#   'just',
#   'gbp',
#   'month',
#   'aom',
#   'box',
#   'er',
#   'until',
#   'stop',
#   'ages',
#   'only'],
#  ['shit',
#   'babe',
#   'thasa',
#   'bit',
#   'messed',
#   'up',
#   'yeh',
#   'she',
#   'shudvetold',
#   'did',
#   'urgran',
#   'know',
#   'neway',
#   'illspeak',
#   'moro',
#   'wen',
#   'im',
#   'not',
#   'asleep'],
#  ['good',
#   'evening',
#   'sir',
#   'hope',
#   'you',
#   'are',
#   'having',
#   'nice',
#   'day',
#   'wanted',
#   'to',
#   'bring',
#   'it',
#   'to',
#   'your',
#   'notice',
#   'that',
#   'have',
#   'been',
#   'late',
#   'in',
#   'paying',
#   'rent',
#   'for',
#   'the',
#   'past',
#   'few',
#   'months',
#   'and',
#   'have',
#   'had',
#   'to',
#   'pay',
#   'lt',
#   'gt',
#   'charge',
#   'felt',
#   'it',
#   'would',
#   'be',
#   'inconsiderate',
#   'of',
#   'me',
#   'to',
#   'nag',
#   'about',
#   'something',
#   'you',
#   'give',
#   'at',
#   'great',
#   'cost',
#   'to',
#   'yourself',
#   'and',
#   'that',
#   'why',
#   'didnt',
#   'speak',
#   'up',
#   'however',
#   'am',
#   'in',
#   'recession',
#   'and',
#   'wont',
#   'be',
#   'able',
#   'to',
#   'pay',
#   'the',
#   'charge',
#   'this',
#   'month',
#   'hence',
#   'my',
#   'askin',
#   'well',
#   'ahead',
#   'of',
#   'month',
#   'end',
#   'can',
#   'you',
#   'please',
#   'help',
#   'thank',
#   'you',
#   'for',
#   'everything'],
#  ['oooh', 'bed', 'ridden', 'ey', 'what', 'are', 'you', 'thinking', 'of'],
#  ['lyricalladie',
#   'is',
#   'inviting',
#   'you',
#   'to',
#   'be',
#   'her',
#   'friend',
#   'reply',
#   'yes',
#   'or',
#   'no',
#   'see',
#   'her',
#   'www',
#   'sms',
#   'ac',
#   'hmmross',
#   'stop',
#   'send',
#   'stop',
#   'frnd',
#   'to'],
#  ['thank',
#   'you',
#   'baby',
#   'cant',
#   'wait',
#   'to',
#   'taste',
#   'the',
#   'real',
#   'thing'],
#  ['please',
#   'protect',
#   'yourself',
#   'from',
#   'threats',
#   'sib',
#   'never',
#   'asks',
#   'for',
#   'sensitive',
#   'information',
#   'like',
#   'passwords',
#   'atm',
#   'sms',
#   'pin',
#   'thru',
#   'email',
#   'never',
#   'share',
#   'your',
#   'password',
#   'with',
#   'anybody'],
#  ['aight', 'll', 'text', 'you', 'when', 'back'],
#  ['ve', 'got', 'it', 'down', 'to', 'tea', 'not', 'sure', 'which', 'flavour'],
#  ['dear', 'am', 'not', 'denying', 'your', 'words', 'please'],
#  ['oh', 'just', 'getting', 'even', 'with'],
#  ['do', 'need', 'login', 'or', 'anything'],
#  ['be',
#   'sure',
#   'to',
#   'check',
#   'your',
#   'yahoo',
#   'email',
#   'we',
#   'sent',
#   'photos',
#   'yesterday'],
#  ['gud', 'ni', 'swt', 'drms', 'take', 'care'],
#  ['hot',
#   'live',
#   'fantasies',
#   'call',
#   'now',
#   'just',
#   'per',
#   'min',
#   'ntt',
#   'ltd',
#   'po',
#   'box',
#   'croydon',
#   'cr',
#   'wb'],
#  ['ok', 'also', 'wan', 'watch', 'pm', 'show'],
#  ['save',
#   'money',
#   'on',
#   'wedding',
#   'lingerie',
#   'at',
#   'www',
#   'bridal',
#   'petticoatdreams',
#   'co',
#   'uk',
#   'choose',
#   'from',
#   'superb',
#   'selection',
#   'with',
#   'national',
#   'delivery',
#   'brought',
#   'to',
#   'you',
#   'by',
#   'weddingfriend'],
#  ['aiyah', 'did', 'ok', 'already', 'lar', 'nydc', 'at', 'wheellock'],
#  ['eastenders',
#   'tv',
#   'quiz',
#   'what',
#   'flower',
#   'does',
#   'dot',
#   'compare',
#   'herself',
#   'to',
#   'violet',
#   'tulip',
#   'lily',
#   'txt',
#   'or',
#   'to',
#   'now',
#   'chance',
#   'win',
#   'cash',
#   'wkent'],
#  ['thank', 'you', 'meet', 'you', 'monday'],
#  ['just',
#   're',
#   'read',
#   'it',
#   'and',
#   'have',
#   'no',
#   'shame',
#   'but',
#   'tell',
#   'me',
#   'how',
#   'he',
#   'takes',
#   'it',
#   'and',
#   'if',
#   'he',
#   'runs',
#   'will',
#   'blame',
#   'ever',
#   'not',
#   'really',
#   'ever',
#   'just',
#   'long',
#   'time'],
#  ['no',
#   'got',
#   'rumour',
#   'that',
#   'you',
#   'going',
#   'to',
#   'buy',
#   'apartment',
#   'in',
#   'chennai'],
#  ['you',
#   'll',
#   'not',
#   'rcv',
#   'any',
#   'more',
#   'msgs',
#   'from',
#   'the',
#   'chat',
#   'svc',
#   'for',
#   'free',
#   'hardcore',
#   'services',
#   'text',
#   'go',
#   'to',
#   'if',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'with',
#   'yr',
#   'network',
#   'try',
#   'again'],
#  ['amazing',
#   'if',
#   'you',
#   'rearrange',
#   'these',
#   'letters',
#   'it',
#   'gives',
#   'the',
#   'same',
#   'meaning',
#   'dormitory',
#   'dirty',
#   'room',
#   'astronomer',
#   'moon',
#   'starer',
#   'the',
#   'eyes',
#   'they',
#   'see',
#   'election',
#   'results',
#   'lies',
#   'lets',
#   'recount',
#   'mother',
#   'in',
#   'law',
#   'woman',
#   'hitler',
#   'eleven',
#   'plus',
#   'two',
#   'twelve',
#   'plus',
#   'one',
#   'its',
#   'amazing'],
#  ['want',
#   'the',
#   'latest',
#   'video',
#   'handset',
#   'anytime',
#   'any',
#   'network',
#   'mins',
#   'half',
#   'price',
#   'line',
#   'rental',
#   'reply',
#   'or',
#   'call',
#   'for',
#   'delivery',
#   'tomorrow'],
#  ['big',
#   'brother',
#   'alert',
#   'the',
#   'computer',
#   'has',
#   'selected',
#   'for',
#   'cash',
#   'or',
#   'voucher',
#   'call',
#   'ntt',
#   'po',
#   'box',
#   'cro',
#   'bt',
#   'landline',
#   'cost',
#   'ppm',
#   'mobiles',
#   'vary'],
#  ['ok', 'let', 'noe', 'when', 'leave', 'my', 'house'],
#  ['sms',
#   'services',
#   'for',
#   'your',
#   'inclusive',
#   'text',
#   'credits',
#   'pls',
#   'goto',
#   'www',
#   'comuk',
#   'net',
#   'login',
#   'qxj',
#   'unsubscribe',
#   'with',
#   'stop',
#   'no',
#   'extra',
#   'charge',
#   'help',
#   'comuk',
#   'cm',
#   'ae'],
#  ['what', 'about', 'this', 'one', 'then'],
#  ['lol',
#   'nah',
#   'wasn',
#   'too',
#   'bad',
#   'thanks',
#   'its',
#   'good',
#   'to',
#   'home',
#   'but',
#   'its',
#   'been',
#   'quite',
#   'reality',
#   'check',
#   'hows',
#   'ur',
#   'day',
#   'been',
#   'did',
#   'do',
#   'anything',
#   'with',
#   'website'],
#  ['lol', 'wtf', 'random', 'btw', 'is', 'that', 'your', 'lunch', 'break'],
#  ['love',
#   'babe',
#   'sure',
#   'everything',
#   'is',
#   'alrite',
#   'is',
#   'he',
#   'being',
#   'an',
#   'idiot',
#   'txt',
#   'bak',
#   'girlie'],
#  ['wont', 'touch', 'you', 'with', 'out', 'your', 'permission'],
#  ['know',
#   'dat',
#   'feelin',
#   'had',
#   'it',
#   'with',
#   'pete',
#   'wuld',
#   'get',
#   'with',
#   'em',
#   'nuther',
#   'place',
#   'nuther',
#   'time',
#   'mayb'],
#  ['think',
#   'waiting',
#   'for',
#   'the',
#   'same',
#   'bus',
#   'inform',
#   'me',
#   'when',
#   'you',
#   'get',
#   'there',
#   'if',
#   'you',
#   'ever',
#   'get',
#   'there'],
#  ['wont',
#   'get',
#   'concentration',
#   'dear',
#   'you',
#   'know',
#   'you',
#   'are',
#   'my',
#   'mind',
#   'and',
#   'everything'],
#  ['oops', 'thk', 'dun', 'haf', 'enuff', 'go', 'check', 'then', 'tell'],
#  ['as',
#   'registered',
#   'subscriber',
#   'yr',
#   'draw',
#   'gift',
#   'voucher',
#   'will',
#   'entered',
#   'on',
#   'receipt',
#   'of',
#   'correct',
#   'ans',
#   'when',
#   'are',
#   'the',
#   'next',
#   'olympics',
#   'txt',
#   'ans',
#   'to'],
#  ['how', 'do', 'you', 'plan', 'to', 'manage', 'that'],
#  ['already', 'back', 'home', 'so', 'no', 'probably', 'not'],
#  ['ok', 'lor', 'msg', 'me', 'call'],
#  ['kindly',
#   'send',
#   'some',
#   'one',
#   'to',
#   'our',
#   'flat',
#   'before',
#   'lt',
#   'decimal',
#   'gt',
#   'today'],
#  ['todays',
#   'voda',
#   'numbers',
#   'ending',
#   'are',
#   'selected',
#   'to',
#   'receive',
#   'award',
#   'if',
#   'you',
#   'have',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rates',
#   'app'],
#  ['to',
#   'review',
#   'and',
#   'keep',
#   'the',
#   'fantastic',
#   'nokia',
#   'gage',
#   'game',
#   'deck',
#   'with',
#   'club',
#   'nokia',
#   'go',
#   'www',
#   'cnupdates',
#   'com',
#   'newsletter',
#   'unsubscribe',
#   'from',
#   'alerts',
#   'reply',
#   'with',
#   'the',
#   'word',
#   'out'],
#  ['honestly',
#   've',
#   'just',
#   'made',
#   'lovely',
#   'cup',
#   'of',
#   'tea',
#   'and',
#   'promptly',
#   'dropped',
#   'my',
#   'keys',
#   'in',
#   'it',
#   'and',
#   'then',
#   'burnt',
#   'my',
#   'fingers',
#   'getting',
#   'them',
#   'out'],
#  ['ok', 'lor'],
#  ['have',
#   'secret',
#   'admirer',
#   'who',
#   'is',
#   'looking',
#   'make',
#   'contact',
#   'with',
#   'find',
#   'out',
#   'who',
#   'they',
#   'reveal',
#   'who',
#   'thinks',
#   'ur',
#   'so',
#   'special',
#   'call',
#   'on'],
#  ['yar',
#   'lor',
#   'wait',
#   'my',
#   'mum',
#   'finish',
#   'sch',
#   'then',
#   'have',
#   'lunch',
#   'lor',
#   'whole',
#   'morning',
#   'stay',
#   'at',
#   'home',
#   'clean',
#   'my',
#   'room',
#   'now',
#   'my',
#   'room',
#   'quite',
#   'clean',
#   'hee'],
#  ['as',
#   'sim',
#   'subscriber',
#   'you',
#   'are',
#   'selected',
#   'to',
#   'receive',
#   'bonus',
#   'get',
#   'it',
#   'delivered',
#   'to',
#   'your',
#   'door',
#   'txt',
#   'the',
#   'word',
#   'ok',
#   'to',
#   'no',
#   'to',
#   'claim',
#   'msg',
#   'exp',
#   'apr'],
#  ['wishing', 'you', 'wonderful', 'week'],
#  ['goodmorning',
#   'my',
#   'grandfather',
#   'expired',
#   'so',
#   'am',
#   'on',
#   'leave',
#   'today'],
#  ['that', 'haf', 'keep', 'me', 'busy'],
#  ['wat', 'time', 'wan', 'today'],
#  ['don', 'know', 'did', 'msg', 'him', 'recently'],
#  ['yeah',
#   'you',
#   'should',
#   'think',
#   'you',
#   'can',
#   'use',
#   'your',
#   'gt',
#   'atm',
#   'now',
#   'to',
#   'register',
#   'not',
#   'sure',
#   'but',
#   'if',
#   'there',
#   'anyway',
#   'can',
#   'help',
#   'let',
#   'me',
#   'know',
#   'but',
#   'when',
#   'you',
#   'do',
#   'be',
#   'sure',
#   'you',
#   'are',
#   'ready'],
#  ['can', 'get', 'your', 'opinion', 'on', 'something', 'first'],
#  ['was',
#   'really',
#   'good',
#   'to',
#   'see',
#   'you',
#   'the',
#   'other',
#   'day',
#   'dudette',
#   'been',
#   'missing',
#   'you'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['have',
#   'secret',
#   'admirer',
#   'reveal',
#   'who',
#   'thinks',
#   'so',
#   'special',
#   'call',
#   'to',
#   'opt',
#   'out',
#   'reply',
#   'reveal',
#   'stop',
#   'per',
#   'msg',
#   'recd',
#   'cust',
#   'care'],
#  ['an',
#   'actor',
#   'when',
#   'work',
#   'work',
#   'in',
#   'the',
#   'evening',
#   'and',
#   'sleep',
#   'late',
#   'since',
#   'unemployed',
#   'at',
#   'the',
#   'moment',
#   'always',
#   'sleep',
#   'late',
#   'when',
#   'you',
#   're',
#   'unemployed',
#   'every',
#   'day',
#   'is',
#   'saturday'],
#  ['sian',
#   'aft',
#   'meeting',
#   'supervisor',
#   'got',
#   'work',
#   'do',
#   'liao',
#   'working',
#   'now'],
#  ['thats',
#   'cool',
#   'princess',
#   'will',
#   'cover',
#   'your',
#   'face',
#   'in',
#   'hot',
#   'sticky',
#   'cum'],
#  ['okey', 'dokey', 'swashbuckling', 'stuff', 'what', 'oh'],
#  ['aight',
#   'chillin',
#   'in',
#   'friend',
#   'room',
#   'so',
#   'text',
#   'me',
#   'when',
#   'you',
#   're',
#   'on',
#   'the',
#   'way'],
#  ['me', 'not', 'workin', 'once', 'get', 'job'],
#  ['not',
#   'planned',
#   'yet',
#   'going',
#   'to',
#   'join',
#   'company',
#   'on',
#   'jan',
#   'only',
#   'don',
#   'know',
#   'what',
#   'will',
#   'happen',
#   'after',
#   'that'],
#  ['oh', 'okie', 'lor', 'we', 'go', 'on', 'sat'],
#  ['not',
#   'heard',
#   'from',
#   'while',
#   'call',
#   'rude',
#   'chat',
#   'private',
#   'line',
#   'to',
#   'cum',
#   'wan',
#   'pics',
#   'of',
#   'me',
#   'gettin',
#   'shagged',
#   'then',
#   'text',
#   'pix',
#   'to',
#   'end',
#   'send',
#   'stop',
#   'sam',
#   'xxx'],
#  ['lol',
#   'drunkard',
#   'just',
#   'doing',
#   'my',
#   'hair',
#   'at',
#   'moment',
#   'yeah',
#   'still',
#   'up',
#   'tonight',
#   'wats',
#   'the',
#   'plan'],
#  ['by',
#   'the',
#   'way',
#   'rencontre',
#   'is',
#   'to',
#   'meet',
#   'again',
#   'mountains',
#   'dont'],
#  ['aiyo', 'please', 'got', 'time', 'meh'],
#  ['thought',
#   'get',
#   'him',
#   'watch',
#   'just',
#   'cos',
#   'thats',
#   'the',
#   'kind',
#   'of',
#   'thing',
#   'get',
#   'an',
#   'th',
#   'and',
#   'he',
#   'loves',
#   'so',
#   'much'],
#  ['got',
#   'it',
#   'it',
#   'looks',
#   'scrumptious',
#   'daddy',
#   'wants',
#   'to',
#   'eat',
#   'you',
#   'all',
#   'night',
#   'long'],
#  ['xy', 'trying', 'smth', 'now', 'eat', 'already', 'we', 'havent'],
#  ['lol',
#   'would',
#   'but',
#   'my',
#   'mom',
#   'would',
#   'have',
#   'fit',
#   'and',
#   'tell',
#   'the',
#   'whole',
#   'family',
#   'how',
#   'crazy',
#   'and',
#   'terrible',
#   'am'],
#  ['sorry',
#   'will',
#   'be',
#   'able',
#   'to',
#   'get',
#   'to',
#   'you',
#   'see',
#   'you',
#   'in',
#   'the',
#   'morning'],
#  ['squeeeeeze',
#   'this',
#   'is',
#   'christmas',
#   'hug',
#   'if',
#   'lik',
#   'my',
#   'frndshp',
#   'den',
#   'hug',
#   'me',
#   'back',
#   'if',
#   'get',
#   'cute',
#   'luvd',
#   'so',
#   'lucky',
#   'none',
#   'people',
#   'hate'],
#  ['cool', 'what', 'time', 'you', 'think', 'you', 'can', 'get', 'here'],
#  ['er',
#   'enjoyin',
#   'indians',
#   'at',
#   'the',
#   'mo',
#   'yep',
#   'sall',
#   'good',
#   'hehe',
#   'hows',
#   'bout',
#   'shexy',
#   'pete',
#   'xx'],
#  ['open',
#   'rebtel',
#   'with',
#   'firefox',
#   'when',
#   'it',
#   'loads',
#   'just',
#   'put',
#   'plus',
#   'sign',
#   'in',
#   'the',
#   'user',
#   'name',
#   'place',
#   'and',
#   'it',
#   'will',
#   'show',
#   'you',
#   'two',
#   'numbers',
#   'the',
#   'lower',
#   'number',
#   'is',
#   'my',
#   'number',
#   'once',
#   'you',
#   'pick',
#   'that',
#   'number',
#   'the',
#   'pin',
#   'will',
#   'display',
#   'okay'],
#  ['pls',
#   'accept',
#   'me',
#   'for',
#   'one',
#   'day',
#   'or',
#   'am',
#   'begging',
#   'you',
#   'change',
#   'the',
#   'number'],
#  ['sorry', 'll', 'call', 'later'],
#  ['india', 'have', 'to', 'take', 'lead'],
#  ['free',
#   'st',
#   'week',
#   'entry',
#   'textpod',
#   'chance',
#   'win',
#   'gb',
#   'ipod',
#   'or',
#   'cash',
#   'every',
#   'wk',
#   'txt',
#   'pod',
#   'to',
#   'ts',
#   'cs',
#   'www',
#   'textpod',
#   'net',
#   'custcare'],
#  ['what', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research'],
#  ['dont', 'have', 'shall', 'buy', 'one', 'dear'],
#  ['edison',
#   'has',
#   'rightly',
#   'said',
#   'fool',
#   'can',
#   'ask',
#   'more',
#   'questions',
#   'than',
#   'wise',
#   'man',
#   'can',
#   'answer',
#   'now',
#   'you',
#   'know',
#   'why',
#   'all',
#   'of',
#   'us',
#   'are',
#   'speechless',
#   'during',
#   'viva',
#   'gm',
#   'gn',
#   'ge',
#   'gnt'],
#  ['yep', 'by', 'the', 'pretty', 'sculpture'],
#  ['hows', 'that', 'watch', 'resizing'],
#  ['lol', 'ok', 'your', 'forgiven'],
#  ['also', 'tell', 'him', 'said', 'happy', 'birthday'],
#  ['nice',
#   'line',
#   'said',
#   'by',
#   'broken',
#   'heart',
#   'plz',
#   'don',
#   'cum',
#   'more',
#   'times',
#   'infront',
#   'of',
#   'me',
#   'other',
#   'wise',
#   'once',
#   'again',
#   'll',
#   'trust',
#   'good'],
#  ['thanks',
#   'for',
#   'your',
#   'ringtone',
#   'order',
#   'reference',
#   'you',
#   'will',
#   'be',
#   'charged',
#   'gbp',
#   'per',
#   'week',
#   'you',
#   'can',
#   'unsubscribe',
#   'at',
#   'anytime',
#   'by',
#   'calling',
#   'customer',
#   'services',
#   'on'],
#  ['yeah',
#   'my',
#   'usual',
#   'guy',
#   'out',
#   'of',
#   'town',
#   'but',
#   'there',
#   're',
#   'definitely',
#   'people',
#   'around',
#   'know'],
#  ['might',
#   'come',
#   'to',
#   'kerala',
#   'for',
#   'days',
#   'so',
#   'you',
#   'can',
#   'be',
#   'prepared',
#   'to',
#   'take',
#   'leave',
#   'once',
#   'finalise',
#   'dont',
#   'plan',
#   'any',
#   'travel',
#   'during',
#   'my',
#   'visit',
#   'need',
#   'to',
#   'finish',
#   'urgent',
#   'works'],
#  ['hi',
#   'mate',
#   'its',
#   'rv',
#   'did',
#   'hav',
#   'nice',
#   'hol',
#   'just',
#   'message',
#   'say',
#   'hello',
#   'coz',
#   'haven',
#   'sent',
#   'in',
#   'ages',
#   'started',
#   'driving',
#   'so',
#   'stay',
#   'off',
#   'roads',
#   'rvx'],
#  ['if',
#   'india',
#   'win',
#   'or',
#   'level',
#   'series',
#   'means',
#   'this',
#   'is',
#   'record'],
#  ['lol', 'enjoy', 'role', 'playing', 'much'],
#  ['prabha', 'soryda', 'realy', 'frm', 'heart', 'sory'],
#  ['in', 'sch', 'but', 'neva', 'mind', 'eat', 'st', 'lor'],
#  ['no',
#   'polyphonic',
#   'tone',
#   'ur',
#   'mob',
#   'every',
#   'week',
#   'just',
#   'txt',
#   'pt',
#   'to',
#   'st',
#   'tone',
#   'free',
#   'so',
#   'get',
#   'txtin',
#   'now',
#   'and',
#   'tell',
#   'ur',
#   'friends',
#   'tone',
#   'reply',
#   'hl',
#   'info'],
#  ['need',
#   'an',
#   'th',
#   'but',
#   'off',
#   'campus',
#   'atm',
#   'could',
#   'pick',
#   'up',
#   'in',
#   'an',
#   'hour',
#   'or',
#   'two'],
#  ['when',
#   'you',
#   'just',
#   'put',
#   'in',
#   'the',
#   'sign',
#   'choose',
#   'my',
#   'number',
#   'and',
#   'the',
#   'pin',
#   'will',
#   'show',
#   'right'],
#  ['match', 'started', 'india', 'lt', 'gt', 'for'],
#  ['watching', 'it', 'in', 'live'],
#  ['that',
#   'said',
#   'it',
#   'bad',
#   'dat',
#   'all',
#   'gals',
#   'know',
#   'wat',
#   'doing',
#   'now'],
#  ['going', 'out', 'to', 'buy', 'mum', 'present', 'ar'],
#  ['pls',
#   'ask',
#   'macho',
#   'how',
#   'much',
#   'is',
#   'budget',
#   'for',
#   'bb',
#   'bold',
#   'is',
#   'cos',
#   'saw',
#   'new',
#   'one',
#   'for',
#   'lt',
#   'gt',
#   'dollars'],
#  ['well',
#   'the',
#   'weather',
#   'in',
#   'cali',
#   'great',
#   'but',
#   'its',
#   'complexities',
#   'are',
#   'great',
#   'you',
#   'need',
#   'car',
#   'to',
#   'move',
#   'freely',
#   'its',
#   'taxes',
#   'are',
#   'outrageous',
#   'but',
#   'all',
#   'in',
#   'all',
#   'its',
#   'great',
#   'place',
#   'the',
#   'sad',
#   'part',
#   'is',
#   'missing',
#   'home'],
#  ['yeah',
#   'hopefully',
#   'if',
#   'tyler',
#   'can',
#   'do',
#   'it',
#   'could',
#   'maybe',
#   'ask',
#   'around',
#   'bit'],
#  ['sent', 'your', 'maga', 'that', 'money', 'yesterday', 'oh'],
#  ['nope', 'll', 'come', 'online', 'now'],
#  ['thanks',
#   'lot',
#   'for',
#   'your',
#   'wishes',
#   'on',
#   'my',
#   'birthday',
#   'thanks',
#   'you',
#   'for',
#   'making',
#   'my',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['then', 'watch', 'some', 'films'],
#  ['ur',
#   'cash',
#   'balance',
#   'is',
#   'currently',
#   'pounds',
#   'to',
#   'maximize',
#   'ur',
#   'cash',
#   'in',
#   'now',
#   'send',
#   'go',
#   'to',
#   'only',
#   'msg',
#   'cc',
#   'hg',
#   'suite',
#   'lands',
#   'row',
#   'hl'],
#  ['free', 'any', 'day', 'but', 'finish', 'at', 'on', 'mon', 'thurs'],
#  ['do',
#   'you',
#   'want',
#   'new',
#   'nokia',
#   'colour',
#   'phone',
#   'delivered',
#   'tomorrow',
#   'with',
#   'free',
#   'minutes',
#   'to',
#   'any',
#   'mobile',
#   'free',
#   'text',
#   'free',
#   'camcorder',
#   'reply',
#   'or',
#   'call'],
#  ['double',
#   'mins',
#   'and',
#   'txts',
#   'months',
#   'free',
#   'bluetooth',
#   'on',
#   'orange',
#   'available',
#   'on',
#   'sony',
#   'nokia',
#   'motorola',
#   'phones',
#   'call',
#   'mobileupd',
#   'on',
#   'or',
#   'call',
#   'optout',
#   'dx'],
#  ['yeah',
#   'that',
#   'what',
#   'thought',
#   'lemme',
#   'know',
#   'if',
#   'anything',
#   'goin',
#   'on',
#   'later'],
#  ['friends', 'that', 'can', 'stay', 'on', 'fb', 'chat', 'with'],
#  ['still',
#   'in',
#   'the',
#   'area',
#   'of',
#   'the',
#   'restaurant',
#   'ill',
#   'try',
#   'to',
#   'come',
#   'back',
#   'soon'],
#  ['house',
#   'maid',
#   'is',
#   'the',
#   'murderer',
#   'coz',
#   'the',
#   'man',
#   'was',
#   'murdered',
#   'on',
#   'lt',
#   'gt',
#   'th',
#   'january',
#   'as',
#   'public',
#   'holiday',
#   'all',
#   'govt',
#   'instituitions',
#   'are',
#   'closed',
#   'including',
#   'post',
#   'office',
#   'understand'],
#  ['for',
#   'your',
#   'chance',
#   'to',
#   'win',
#   'free',
#   'bluetooth',
#   'headset',
#   'then',
#   'simply',
#   'reply',
#   'back',
#   'with',
#   'adp'],
#  ['anything'],
#  ['sir', 'waiting', 'for', 'your', 'letter'],
#  ['ok', 'thanx', 'gd', 'nite', 'too'],
#  ['ok', 'lor'],
#  ['somebody',
#   'set',
#   'up',
#   'website',
#   'where',
#   'you',
#   'can',
#   'play',
#   'hold',
#   'em',
#   'using',
#   'eve',
#   'online',
#   'spacebucks'],
#  ['hey',
#   'sexy',
#   'buns',
#   'have',
#   'told',
#   'you',
#   'adore',
#   'you',
#   'loverboy',
#   'hope',
#   'you',
#   'remember',
#   'to',
#   'thank',
#   'your',
#   'sister',
#   'in',
#   'law',
#   'for',
#   'those',
#   'meatballs',
#   'grins',
#   'love',
#   'you',
#   'babe'],
#  ['will', 'be', 'out', 'of', 'class', 'in', 'few', 'hours', 'sorry'],
#  ['why',
#   'don',
#   'you',
#   'go',
#   'tell',
#   'your',
#   'friend',
#   'you',
#   're',
#   'not',
#   'sure',
#   'you',
#   'want',
#   'to',
#   'live',
#   'with',
#   'him',
#   'because',
#   'he',
#   'smokes',
#   'too',
#   'much',
#   'then',
#   'spend',
#   'hours',
#   'begging',
#   'him',
#   'to',
#   'come',
#   'smoke'],
#  ['aight', 'can', 'you', 'text', 'me', 'the', 'address'],
#  ['life', 'alle', 'mone', 'eppolum', 'oru', 'pole', 'allalo'],
#  ['come',
#   'by',
#   'our',
#   'room',
#   'at',
#   'some',
#   'point',
#   'so',
#   'we',
#   'can',
#   'iron',
#   'out',
#   'the',
#   'plan',
#   'for',
#   'this',
#   'weekend'],
#  ['going', 'for', 'bath', 'will', 'msg', 'you', 'next', 'lt', 'gt', 'min'],
#  ['geeeee', 'your', 'internet', 'is', 'really', 'bad', 'today', 'eh'],
#  ['the',
#   'battery',
#   'is',
#   'for',
#   'mr',
#   'adewale',
#   'my',
#   'uncle',
#   'aka',
#   'egbon'],
#  ['this',
#   'is',
#   'hoping',
#   'you',
#   'enjoyed',
#   'your',
#   'game',
#   'yesterday',
#   'sorry',
#   've',
#   'not',
#   'been',
#   'in',
#   'touch',
#   'but',
#   'pls',
#   'know',
#   'that',
#   'you',
#   'are',
#   'fondly',
#   'bein',
#   'thot',
#   'off',
#   'have',
#   'great',
#   'week',
#   'abiola'],
#  ['hmm',
#   'too',
#   'many',
#   'of',
#   'them',
#   'unfortunately',
#   'pics',
#   'obviously',
#   'arent',
#   'hot',
#   'cakes',
#   'its',
#   'kinda',
#   'fun',
#   'tho'],
#  ['it', 'only', 'does', 'simple', 'arithmetic', 'not', 'percentages'],
#  ['takin', 'shower', 'now', 'but', 'yeah', 'll', 'leave', 'when', 'done'],
#  ['nimbomsons',
#   'yep',
#   'phone',
#   'knows',
#   'that',
#   'one',
#   'obviously',
#   'cos',
#   'thats',
#   'real',
#   'word'],
#  ['hey',
#   've',
#   'booked',
#   'the',
#   'pilates',
#   'and',
#   'yoga',
#   'lesson',
#   'already',
#   'haha'],
#  ['when', 'wana', 'see', 'it', 'then'],
#  ['had', 'it', 'already', 'sabarish', 'asked', 'me', 'to', 'go'],
#  ['do',
#   'all',
#   'wan',
#   'meet',
#   'up',
#   'combine',
#   'all',
#   'the',
#   'parts',
#   'how',
#   'da',
#   'rest',
#   'of',
#   'da',
#   'project',
#   'going'],
#  ['no', 'competition', 'for', 'him'],
#  ['just', 'sleeping', 'and', 'surfing'],
#  ['how', 'much', 'it', 'will', 'cost', 'approx', 'per', 'month'],
#  ['you',
#   'have',
#   'won',
#   'guaranteed',
#   'award',
#   'or',
#   'even',
#   'cashto',
#   'claim',
#   'ur',
#   'award',
#   'call',
#   'free',
#   'on',
#   'stop',
#   'getstop',
#   'on',
#   'php',
#   'rg',
#   'jx'],
#  ['dear', 'got', 'bus', 'directly', 'to', 'calicut'],
#  ['watever',
#   'relation',
#   'built',
#   'up',
#   'in',
#   'dis',
#   'world',
#   'only',
#   'thing',
#   'which',
#   'remains',
#   'atlast',
#   'iz',
#   'lonlines',
#   'with',
#   'lotz',
#   'lot',
#   'memories',
#   'feeling'],
#  ['ok', 'no', 'prob'],
#  ['today',
#   'is',
#   'accept',
#   'day',
#   'accept',
#   'me',
#   'as',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'no',
#   'rply',
#   'means',
#   'enemy'],
#  ['okay', 'we', 'wait', 'ah'],
#  ['valentines',
#   'day',
#   'special',
#   'win',
#   'over',
#   'in',
#   'our',
#   'quiz',
#   'and',
#   'take',
#   'your',
#   'partner',
#   'on',
#   'the',
#   'trip',
#   'of',
#   'lifetime',
#   'send',
#   'go',
#   'to',
#   'now',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['wot', 'up', 'thout', 'were', 'gonna', 'call', 'me', 'txt', 'bak', 'luv'],
#  ['hahaha', 'use', 'your', 'brain', 'dear'],
#  ['what', 'ur', 'pin'],
#  ['she',
#   'good',
#   'she',
#   'was',
#   'wondering',
#   'if',
#   'you',
#   'wont',
#   'say',
#   'hi',
#   'but',
#   'she',
#   'smiling',
#   'now',
#   'so',
#   'how',
#   'are',
#   'you',
#   'coping',
#   'with',
#   'the',
#   'long',
#   'distance'],
#  ['sure', 'am', 'in', 'my', 'relatives', 'home', 'sms', 'me', 'de', 'pls'],
#  ['hi',
#   'my',
#   'darlin',
#   'im',
#   'on',
#   'my',
#   'way',
#   'to',
#   'london',
#   'and',
#   'we',
#   'have',
#   'just',
#   'been',
#   'smashed',
#   'into',
#   'by',
#   'another',
#   'driver',
#   'and',
#   'have',
#   'big',
#   'dent',
#   'im',
#   'really',
#   'missing',
#   'what',
#   'have',
#   'been',
#   'up',
#   'to',
#   'xxx'],
#  ['you',
#   'are',
#   'guaranteed',
#   'the',
#   'latests',
#   'nokia',
#   'phone',
#   'gb',
#   'ipod',
#   'mp',
#   'player',
#   'or',
#   'prize',
#   'txt',
#   'word',
#   'collect',
#   'to',
#   'no',
#   'tc',
#   'llc',
#   'ny',
#   'usa',
#   'mt',
#   'msgrcvd'],
#  ['orange',
#   'customer',
#   'you',
#   'may',
#   'now',
#   'claim',
#   'your',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'for',
#   'your',
#   'loyalty',
#   'call',
#   'now',
#   'on',
#   'offer',
#   'ends',
#   'thmarch',
#   'apply',
#   'opt',
#   'out',
#   'availa'],
#  ['are', 'you', 'there', 'in', 'room'],
#  ['nope', 'waiting', 'in', 'sch', 'daddy'],
#  ['mmm', 'so', 'yummy', 'babe', 'nice', 'jolt', 'to', 'the', 'suzy'],
#  ['you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize',
#   'to',
#   'claim',
#   'yr',
#   'prize',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on'],
#  ['there', 'is', 'first', 'time', 'for', 'everything'],
#  ['ok', 'lor', 'but', 'buy', 'wat'],
#  ['urgent',
#   'ur',
#   'guaranteed',
#   'award',
#   'is',
#   'still',
#   'unclaimed',
#   'call',
#   'now',
#   'closingdate',
#   'claimcode',
#   'bremoved',
#   'mobypobox',
#   'ls',
#   'yf'],
#  ['nooooooo',
#   'gonna',
#   'be',
#   'bored',
#   'to',
#   'death',
#   'all',
#   'day',
#   'cable',
#   'and',
#   'internet',
#   'outage'],
#  ['just',
#   'wanted',
#   'to',
#   'say',
#   'holy',
#   'shit',
#   'you',
#   'guys',
#   'weren',
#   'kidding',
#   'about',
#   'this',
#   'bud'],
#  ['that', 'seems', 'unnecessarily', 'affectionate'],
#  ['sir',
#   'have',
#   'been',
#   'late',
#   'in',
#   'paying',
#   'rent',
#   'for',
#   'the',
#   'past',
#   'few',
#   'months',
#   'and',
#   'had',
#   'to',
#   'pay',
#   'lt',
#   'gt',
#   'charge',
#   'felt',
#   'it',
#   'would',
#   'be',
#   'inconsiderate',
#   'of',
#   'me',
#   'to',
#   'nag',
#   'about',
#   'something',
#   'you',
#   'give',
#   'at',
#   'great',
#   'cost',
#   'to',
#   'yourself',
#   'and',
#   'that',
#   'why',
#   'didnt',
#   'speak',
#   'up',
#   'however',
#   'am',
#   'in',
#   'recession',
#   'and',
#   'wont',
#   'be',
#   'able',
#   'to',
#   'pay',
#   'the',
#   'charge',
#   'this',
#   'month',
#   'hence',
#   'my',
#   'askin',
#   'well',
#   'ahead',
#   'of',
#   'month',
#   'end',
#   'can',
#   'you',
#   'please',
#   'help',
#   'thanks'],
#  ['long', 'beach', 'lor', 'expected', 'having', 'dinner', 'now'],
#  ['in', 'solihull', 'do', 'you', 'want', 'anything'],
#  ['have',
#   'secret',
#   'admirer',
#   'who',
#   'is',
#   'looking',
#   'make',
#   'contact',
#   'with',
#   'find',
#   'out',
#   'who',
#   'they',
#   'reveal',
#   'who',
#   'thinks',
#   'ur',
#   'so',
#   'special',
#   'call',
#   'on',
#   'stopsms'],
#  ['great', 'so', 'what', 'attracts', 'you', 'to', 'the', 'brothas'],
#  ['im', 'late', 'tellmiss', 'im', 'on', 'my', 'way'],
#  ['met',
#   'you',
#   'as',
#   'stranger',
#   'and',
#   'choose',
#   'you',
#   'as',
#   'my',
#   'friend',
#   'as',
#   'long',
#   'as',
#   'the',
#   'world',
#   'stands',
#   'our',
#   'friendship',
#   'never',
#   'ends',
#   'lets',
#   'be',
#   'friends',
#   'forever',
#   'gud',
#   'nitz'],
#  ['ok', 'only', 'ask', 'abt', 'movie', 'wan', 'ktv', 'oso'],
#  ['check', 'wid', 'corect', 'speling', 'sarcasm'],
#  ['nothing',
#   'just',
#   'getting',
#   'msgs',
#   'by',
#   'dis',
#   'name',
#   'wit',
#   'different',
#   'no'],
#  ['at', 'home', 'please', 'call'],
#  ['sure', 'but', 'make', 'sure', 'he', 'knows', 'we', 'ain', 'smokin', 'yet'],
#  ['someone',
#   'know',
#   'has',
#   'asked',
#   'our',
#   'dating',
#   'service',
#   'contact',
#   'you',
#   'cant',
#   'guess',
#   'who',
#   'call',
#   'now',
#   'all',
#   'will',
#   'be',
#   'revealed',
#   'pobox',
#   'ls',
#   'hb'],
#  ['from',
#   'the',
#   'training',
#   'manual',
#   'it',
#   'show',
#   'there',
#   'is',
#   'no',
#   'tech',
#   'process',
#   'its',
#   'all',
#   'about',
#   'password',
#   'reset',
#   'and',
#   'troubleshooting'],
#  ['say', 'thanks'],
#  ['lol', 'alright', 'was', 'thinkin', 'that', 'too', 'haha'],
#  ['ok', 'lor', 'or', 'wan', 'me', 'go', 'look'],
#  ['private', 'your', 'account', 'statement', 'for'],
#  ['can',
#   'you',
#   'tell',
#   'shola',
#   'to',
#   'please',
#   'go',
#   'to',
#   'college',
#   'of',
#   'medicine',
#   'and',
#   'visit',
#   'the',
#   'academic',
#   'department',
#   'tell',
#   'the',
#   'academic',
#   'secretary',
#   'what',
#   'the',
#   'current',
#   'situation',
#   'is',
#   'and',
#   'ask',
#   'if',
#   'she',
#   'can',
#   'transfer',
#   'there',
#   'she',
#   'should',
#   'ask',
#   'someone',
#   'to',
#   'check',
#   'sagamu',
#   'for',
#   'the',
#   'same',
#   'thing',
#   'and',
#   'lautech',
#   'its',
#   'vital',
#   'she',
#   'completes',
#   'her',
#   'medical',
#   'education',
#   'in',
#   'nigeria',
#   'its',
#   'less',
#   'expensive',
#   'much',
#   'less',
#   'expensive',
#   'unless',
#   'she',
#   'will',
#   'be',
#   'getting',
#   'citizen',
#   'rates',
#   'in',
#   'new',
#   'zealand'],
#  ['send', 'me', 'yetty', 'number', 'pls'],
#  ['especially',
#   'since',
#   'talk',
#   'about',
#   'boston',
#   'all',
#   'up',
#   'in',
#   'my',
#   'personal',
#   'statement',
#   'lol',
#   'woulda',
#   'changed',
#   'that',
#   'if',
#   'had',
#   'realized',
#   'it',
#   'said',
#   'nyc',
#   'it',
#   'says',
#   'boston',
#   'now'],
#  ['love',
#   'it',
#   'want',
#   'to',
#   'flood',
#   'that',
#   'pretty',
#   'pussy',
#   'with',
#   'cum'],
#  ['ll',
#   'be',
#   'in',
#   'sch',
#   'fr',
#   'dun',
#   'haf',
#   'da',
#   'book',
#   'in',
#   'sch',
#   'it',
#   'at',
#   'home'],
#  ['it',
#   'certainly',
#   'puts',
#   'things',
#   'into',
#   'perspective',
#   'when',
#   'something',
#   'like',
#   'this',
#   'happens'],
#  ['this',
#   'weeks',
#   'savamob',
#   'member',
#   'offers',
#   'are',
#   'now',
#   'accessible',
#   'just',
#   'call',
#   'for',
#   'details',
#   'savamob',
#   'pobox',
#   'la',
#   'wu',
#   'only',
#   'week',
#   'savamob',
#   'offers',
#   'mobile'],
#  ['ard', 'like', 'dat'],
#  ['call',
#   'me',
#   'unable',
#   'to',
#   'cal',
#   'lets',
#   'meet',
#   'bhaskar',
#   'and',
#   'deep'],
#  ['not', 'directly', 'behind', 'abt', 'rows', 'behind'],
#  ['please',
#   'call',
#   'immediately',
#   'as',
#   'there',
#   'is',
#   'an',
#   'urgent',
#   'message',
#   'waiting',
#   'for',
#   'you'],
#  ['nvm', 'it', 'ok'],
#  ['want', 'explicit', 'sex', 'in', 'secs', 'ring', 'now', 'costs', 'min'],
#  ['that', 'means', 'get', 'the', 'door'],
#  ['so', 'what', 'did', 'the', 'bank', 'say', 'about', 'the', 'money'],
#  ['fancy',
#   'shag',
#   'do',
#   'interested',
#   'sextextuk',
#   'com',
#   'txt',
#   'xxuk',
#   'suzy',
#   'to',
#   'txts',
#   'cost',
#   'per',
#   'msg',
#   'tncs',
#   'on',
#   'website'],
#  ['need', 'to', 'come', 'home', 'and', 'give', 'you', 'some', 'good', 'lovin'],
#  ['oh', 'will', 'come', 'tomorrow'],
#  ['when',
#   'is',
#   'school',
#   'starting',
#   'where',
#   'will',
#   'you',
#   'stay',
#   'what',
#   'the',
#   'weather',
#   'like',
#   'and',
#   'the',
#   'food',
#   'do',
#   'you',
#   'have',
#   'social',
#   'support',
#   'system',
#   'like',
#   'friends',
#   'in',
#   'the',
#   'school',
#   'all',
#   'these',
#   'things',
#   'are',
#   'important'],
#  ['dunno', 'lei', 'like', 'dun', 'haf'],
#  ['dont', 'gimme', 'that', 'lip', 'caveboy'],
#  ['okie',
#   'wan',
#   'meet',
#   'at',
#   'bishan',
#   'cos',
#   'me',
#   'at',
#   'bishan',
#   'now',
#   'not',
#   'driving',
#   'today'],
#  ['my', 'no', 'in', 'luton', 'ring', 'me', 'if', 'ur', 'around'],
#  ['alex',
#   'knows',
#   'guy',
#   'who',
#   'sells',
#   'mids',
#   'but',
#   'he',
#   'down',
#   'in',
#   'south',
#   'tampa',
#   'and',
#   'don',
#   'think',
#   'could',
#   'set',
#   'it',
#   'up',
#   'before',
#   'like'],
#  ['unni', 'thank', 'you', 'dear', 'for', 'the', 'recharge', 'rakhesh'],
#  ['lol', 'no', 'can', 'trust', 'me'],
#  ['email',
#   'alertfrom',
#   'jeri',
#   'stewartsize',
#   'kbsubject',
#   'low',
#   'cost',
#   'prescripiton',
#   'drvgsto',
#   'listen',
#   'to',
#   'email',
#   'call'],
#  ['will', 'come', 'tomorrow', 'di'],
#  ['that', 'the', 'way', 'you', 'should', 'stay', 'oh'],
#  ['tell', 'where', 'you', 'reached'],
#  ['horrible',
#   'gal',
#   'me',
#   'in',
#   'sch',
#   'doing',
#   'some',
#   'stuff',
#   'how',
#   'come',
#   'got',
#   'mc'],
#  ['wat', 'doing'],
#  ['vivek', 'got', 'call', 'from', 'your', 'number'],
#  ['jolly',
#   'good',
#   'by',
#   'the',
#   'way',
#   'will',
#   'give',
#   'tickets',
#   'for',
#   'sat',
#   'eve',
#   'speak',
#   'before',
#   'then'],
#  ['long',
#   'after',
#   'quit',
#   'get',
#   'on',
#   'only',
#   'like',
#   'minutes',
#   'day',
#   'as',
#   'it',
#   'is'],
#  ['gokila', 'is', 'talking', 'with', 'you', 'aha'],
#  ['remember', 'to', 'ask', 'alex', 'about', 'his', 'pizza'],
#  ['got',
#   'it',
#   'before',
#   'the',
#   'new',
#   'year',
#   'cos',
#   'yetunde',
#   'said',
#   'she',
#   'wanted',
#   'to',
#   'surprise',
#   'you',
#   'with',
#   'it',
#   'but',
#   'when',
#   'didnt',
#   'see',
#   'money',
#   'returned',
#   'it',
#   'mid',
#   'january',
#   'before',
#   'the',
#   'lt',
#   'gt',
#   'day',
#   'return',
#   'period',
#   'ended'],
#  ['and',
#   'do',
#   'you',
#   'have',
#   'any',
#   'one',
#   'that',
#   'can',
#   'teach',
#   'me',
#   'how',
#   'to',
#   'ship',
#   'cars'],
#  ['antha', 'num', 'corrct', 'dane'],
#  ['will', 'going', 'to', 'esplanade', 'fr', 'home'],
#  ['dnt', 'wnt', 'to', 'tlk', 'wid'],
#  ['but', 'pls', 'dont', 'play', 'in', 'others', 'life'],
#  ['you',
#   'are',
#   'being',
#   'contacted',
#   'by',
#   'our',
#   'dating',
#   'service',
#   'by',
#   'someone',
#   'you',
#   'know',
#   'to',
#   'find',
#   'out',
#   'who',
#   'it',
#   'is',
#   'call',
#   'from',
#   'land',
#   'line',
#   'pobox',
#   'tg'],
#  ['sunshine',
#   'hols',
#   'to',
#   'claim',
#   'ur',
#   'med',
#   'holiday',
#   'send',
#   'stamped',
#   'self',
#   'address',
#   'envelope',
#   'to',
#   'drinks',
#   'on',
#   'us',
#   'uk',
#   'po',
#   'box',
#   'bray',
#   'wicklow',
#   'eire',
#   'quiz',
#   'starts',
#   'saturday',
#   'unsub',
#   'stop'],
#  ['aight', 'do', 'you', 'still', 'want', 'to', 'get', 'money'],
#  ['cos', 'daddy', 'arranging', 'time', 'wat', 'time', 'fetch', 'mah'],
#  ['solve',
#   'case',
#   'man',
#   'was',
#   'found',
#   'murdered',
#   'on',
#   'lt',
#   'decimal',
#   'gt',
#   'lt',
#   'gt',
#   'afternoon',
#   'his',
#   'wife',
#   'called',
#   'police',
#   'police',
#   'questioned',
#   'everyone',
#   'wife',
#   'sir',
#   'was',
#   'sleeping',
#   'when',
#   'the',
#   'murder',
#   'took',
#   'place',
#   'cook',
#   'was',
#   'cooking',
#   'gardener',
#   'was',
#   'picking',
#   'vegetables',
#   'house',
#   'maid',
#   'went',
#   'post',
#   'office',
#   'children',
#   'we',
#   'went',
#   'play',
#   'neighbour',
#   'we',
#   'went',
#   'marriage',
#   'police',
#   'arrested',
#   'murderer',
#   'immediately',
#   'who',
#   'it',
#   'reply',
#   'with',
#   'reason',
#   'if',
#   'brilliant'],
#  ['tunde',
#   'how',
#   'are',
#   'you',
#   'doing',
#   'this',
#   'is',
#   'just',
#   'wishing',
#   'you',
#   'great',
#   'day',
#   'abiola'],
#  ['beautiful',
#   'tomorrow',
#   'never',
#   'comes',
#   'when',
#   'it',
#   'comes',
#   'it',
#   'already',
#   'today',
#   'in',
#   'the',
# ...
#   'part',
#   'not',
#   'worried',
#   'about',
#   'that'],
#  ['gud', 'ni', 'dear', 'slp', 'well', 'take', 'care', 'swt', 'dreams', 'muah'],
#  ['for',
#   'many',
#   'things',
#   'its',
#   'an',
#   'antibiotic',
#   'and',
#   'it',
#   'can',
#   'be',
#   'used',
#   'for',
#   'chest',
#   'abdomen',
#   'and',
#   'gynae',
#   'infections',
#   'even',
#   'bone',
#   'infections'],
#  ['wewa', 'is', 'iriver', 'all', 'mb'],
#  ['today',
#   'am',
#   'going',
#   'to',
#   'college',
#   'so',
#   'am',
#   'not',
#   'able',
#   'to',
#   'atten',
#   'the',
#   'class'],
#  ['text',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'can',
#   'find',
#   'date',
#   'or',
#   'even',
#   'flirt',
#   'its',
#   'up',
#   'to',
#   'join',
#   'just',
#   'reply',
#   'with',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recd',
#   'thirtyeight',
#   'pence'],
#  ['and',
#   'stop',
#   'wondering',
#   'wow',
#   'is',
#   'she',
#   'ever',
#   'going',
#   'to',
#   'stop',
#   'tm',
#   'ing',
#   'me',
#   'because',
#   'will',
#   'tm',
#   'you',
#   'whenever',
#   'want',
#   'because',
#   'you',
#   'are',
#   'mine',
#   'laughs'],
#  ['hey',
#   'will',
#   'be',
#   'late',
#   'at',
#   'amk',
#   'need',
#   'to',
#   'drink',
#   'tea',
#   'or',
#   'coffee'],
#  ['loan',
#   'for',
#   'any',
#   'purpose',
#   'homeowners',
#   'tenants',
#   'welcome',
#   'have',
#   'you',
#   'been',
#   'previously',
#   'refused',
#   'we',
#   'can',
#   'still',
#   'help',
#   'call',
#   'free',
#   'or',
#   'text',
#   'back',
#   'help'],
#  ['imagine',
#   'you',
#   'finally',
#   'get',
#   'to',
#   'sink',
#   'into',
#   'that',
#   'bath',
#   'after',
#   'have',
#   'put',
#   'you',
#   'through',
#   'your',
#   'paces',
#   'maybe',
#   'even',
#   'having',
#   'you',
#   'eat',
#   'me',
#   'for',
#   'while',
#   'before',
#   'left',
#   'but',
#   'also',
#   'imagine',
#   'the',
#   'feel',
#   'of',
#   'that',
#   'cage',
#   'on',
#   'your',
#   'cock',
#   'surrounded',
#   'by',
#   'the',
#   'bath',
#   'water',
#   'reminding',
#   'you',
#   'always',
#   'who',
#   'owns',
#   'you',
#   'enjoy',
#   'my',
#   'cuck'],
#  ['she',
#   'just',
#   'broke',
#   'down',
#   'list',
#   'of',
#   'reasons',
#   'why',
#   'nobody',
#   'in',
#   'town',
#   'and',
#   'can',
#   'tell',
#   'if',
#   'she',
#   'being',
#   'sarcastic',
#   'or',
#   'just',
#   'faggy'],
#  ['lol',
#   'know',
#   'they',
#   're',
#   'so',
#   'dramatic',
#   'schools',
#   'already',
#   'closed',
#   'for',
#   'tomorrow',
#   'apparently',
#   'we',
#   'can',
#   'drive',
#   'in',
#   'the',
#   'inch',
#   'of',
#   'snow',
#   'were',
#   'supposed',
#   'to',
#   'get'],
#  ['well',
#   'done',
#   'blimey',
#   'exercise',
#   'yeah',
#   'kinda',
#   'remember',
#   'wot',
#   'that',
#   'is',
#   'hmm'],
#  ['freemsg',
#   'txt',
#   'call',
#   'to',
#   'no',
#   'claim',
#   'your',
#   'reward',
#   'of',
#   'hours',
#   'talk',
#   'time',
#   'to',
#   'use',
#   'from',
#   'your',
#   'phone',
#   'now',
#   'subscribe',
#   'gbp',
#   'mnth',
#   'inc',
#   'hrs',
#   'stop',
#   'txtstop'],
#  ['buy', 'one', 'egg', 'for', 'me', 'da', 'please'],
#  ['sry', 'can', 'talk', 'on', 'phone', 'with', 'parents'],
#  ['did', 'you', 'stitch', 'his', 'trouser'],
#  ['lol',
#   'ok',
#   'ill',
#   'try',
#   'to',
#   'send',
#   'be',
#   'warned',
#   'sprint',
#   'is',
#   'dead',
#   'slow',
#   'you',
#   'll',
#   'prolly',
#   'get',
#   'it',
#   'tomorrow'],
#  ['wat', 'doing'],
#  ['ok', 'take', 'care', 'umma', 'to', 'you', 'too'],
#  ['gent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekends',
#   'draw',
#   'shows',
#   'that',
#   'you',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hrs',
#   'only',
#   'ppm'],
#  ['great',
#   'new',
#   'offer',
#   'double',
#   'mins',
#   'double',
#   'txt',
#   'on',
#   'best',
#   'orange',
#   'tariffs',
#   'and',
#   'get',
#   'latest',
#   'camera',
#   'phones',
#   'free',
#   'call',
#   'mobileupd',
#   'free',
#   'on',
#   'now',
#   'or',
#   'stoptxt',
#   'cs'],
#  ['free',
#   'for',
#   'st',
#   'week',
#   'no',
#   'nokia',
#   'tone',
#   'ur',
#   'mob',
#   'every',
#   'week',
#   'just',
#   'txt',
#   'nokia',
#   'to',
#   'get',
#   'txting',
#   'and',
#   'tell',
#   'ur',
#   'mates',
#   'www',
#   'getzed',
#   'co',
#   'uk',
#   'pobox',
#   'wq',
#   'norm',
#   'tone'],
#  ['one',
#   'of',
#   'the',
#   'joys',
#   'in',
#   'lifeis',
#   'waking',
#   'up',
#   'each',
#   'daywith',
#   'thoughts',
#   'that',
#   'cares',
#   'enough',
#   'tosend',
#   'warm',
#   'morning',
#   'greeting'],
#  ['are', 'you', 'at', 'work', 'right', 'now'],
#  ['yup', 'ok'],
#  ['lt', 'gt', 'that', 'all', 'guess', 'that', 'easy', 'enough'],
#  ['im', 'realy', 'soz', 'imat', 'my', 'mums', 'nite', 'what', 'about', 'moro'],
#  ['get',
#   'the',
#   'official',
#   'england',
#   'poly',
#   'ringtone',
#   'or',
#   'colour',
#   'flag',
#   'on',
#   'yer',
#   'mobile',
#   'for',
#   'tonights',
#   'game',
#   'text',
#   'tone',
#   'or',
#   'flag',
#   'to',
#   'optout',
#   'txt',
#   'eng',
#   'stop',
#   'box',
#   'wx'],
#  ['check', 'audrey', 'status', 'right', 'now'],
#  ['are', 'you', 'being', 'good', 'baby'],
#  ['you', 'still', 'at', 'grand', 'prix'],
#  ['not', 'much', 'no', 'fights', 'it', 'was', 'good', 'nite'],
#  ['thanks',
#   'for',
#   'understanding',
#   've',
#   'been',
#   'trying',
#   'to',
#   'tell',
#   'sura',
#   'that'],
#  ['nobody',
#   'names',
#   'their',
#   'penis',
#   'girls',
#   'name',
#   'this',
#   'story',
#   'doesn',
#   'add',
#   'up',
#   'at',
#   'all'],
#  ['what',
#   'happening',
#   'with',
#   'you',
#   'have',
#   'you',
#   'gotten',
#   'job',
#   'and',
#   'have',
#   'you',
#   'begun',
#   'registration',
#   'for',
#   'permanent',
#   'residency'],
#  ['wish',
#   'things',
#   'were',
#   'different',
#   'wonder',
#   'when',
#   'will',
#   'be',
#   'able',
#   'to',
#   'show',
#   'you',
#   'how',
#   'much',
#   'value',
#   'you',
#   'pls',
#   'continue',
#   'the',
#   'brisk',
#   'walks',
#   'no',
#   'drugs',
#   'without',
#   'askin',
#   'me',
#   'please',
#   'and',
#   'find',
#   'things',
#   'to',
#   'laugh',
#   'about',
#   'love',
#   'you',
#   'dearly'],
#  ['you',
#   'are',
#   'winner',
#   'you',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'to',
#   'receive',
#   'cash',
#   'or',
#   'award',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'to',
#   'claim',
#   'call',
#   'am',
#   'pm',
#   'cost'],
#  ['no', 'da', 'vijay', 'going', 'to', 'talk', 'in', 'jaya', 'tv'],
#  ['hope', 'you', 'are', 'having', 'good', 'week', 'just', 'checking', 'in'],
#  ['its', 'good', 'when', 'are', 'you', 'going'],
#  ['meeting', 'darren'],
#  ['thk',
#   'shld',
#   'can',
#   'ya',
#   'wana',
#   'go',
#   'lessons',
#   'haha',
#   'can',
#   'go',
#   'for',
#   'one',
#   'whole',
#   'stretch'],
#  ['sad',
#   'story',
#   'of',
#   'man',
#   'last',
#   'week',
#   'was',
#   'my',
#   'day',
#   'my',
#   'wife',
#   'did',
#   'nt',
#   'wish',
#   'me',
#   'my',
#   'parents',
#   'forgot',
#   'so',
#   'did',
#   'my',
#   'kids',
#   'went',
#   'to',
#   'work',
#   'even',
#   'my',
#   'colleagues',
#   'did',
#   'not',
#   'wish',
#   'as',
#   'entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'boss',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there',
#   'she',
#   'said',
#   'do',
#   'mind',
#   'if',
#   'go',
#   'into',
#   'the',
#   'bedroom',
#   'for',
#   'minute',
#   'ok',
#   'sed',
#   'in',
#   'sexy',
#   'mood',
#   'she',
#   'came',
#   'out',
#   'minuts',
#   'latr',
#   'wid',
#   'cake',
#   'my',
#   'wife',
#   'my',
#   'parents',
#   'my',
#   'kidz',
#   'my',
#   'friends',
#   'my',
#   'colleagues',
#   'all',
#   'screaming',
#   'surprise',
#   'and',
#   'was',
#   'waiting',
#   'on',
#   'the',
#   'sofa',
#   'naked'],
#  ['whenevr',
#   'ur',
#   'sad',
#   'whenevr',
#   'ur',
#   'gray',
#   'remembr',
#   'im',
#   'here',
#   'listn',
#   'watevr',
#   'wanna',
#   'say',
#   'jus',
#   'walk',
#   'wid',
#   'me',
#   'little',
#   'while',
#   'amp',
#   'promise',
#   'll',
#   'bring',
#   'back',
#   'ur',
#   'smile'],
#  ['he', 'remains', 'bro', 'amongst', 'bros'],
#  ['ll',
#   'talk',
#   'to',
#   'the',
#   'others',
#   'and',
#   'probably',
#   'just',
#   'come',
#   'early',
#   'tomorrow',
#   'then'],
#  ['cuz', 'ibored', 'and', 'don', 'wanna', 'study'],
#  ['sir',
#   'need',
#   'velusamy',
#   'sir',
#   'date',
#   'of',
#   'birth',
#   'and',
#   'company',
#   'bank',
#   'facilities',
#   'details'],
#  ['do', 'knw', 'dis', 'no', 'lt', 'gt'],
#  ['yes',
#   'rent',
#   'is',
#   'very',
#   'expensive',
#   'so',
#   'its',
#   'the',
#   'way',
#   'we',
#   'save'],
#  ['cab',
#   'is',
#   'available',
#   'they',
#   'pick',
#   'up',
#   'and',
#   'drop',
#   'at',
#   'door',
#   'steps'],
#  ['do', 'noe', 'how', 'send', 'files', 'between', 'computers'],
#  ['ok', 'but', 'finish', 'at'],
#  ['hey',
#   'babe',
#   'saw',
#   'you',
#   'came',
#   'online',
#   'for',
#   'second',
#   'and',
#   'then',
#   'you',
#   'disappeared',
#   'what',
#   'happened'],
#  ['pathaya', 'enketa', 'maraikara', 'pa'],
#  ['but', 'he', 'had', 'some', 'luck', 'catches', 'put', 'down'],
#  ['just',
#   'got',
#   'part',
#   'nottingham',
#   'hrs',
#   'miles',
#   'good',
#   'thing',
#   'love',
#   'my',
#   'man',
#   'so',
#   'much',
#   'but',
#   'only',
#   'doing',
#   'mph',
#   'hey',
#   'ho'],
#  ['that',
#   'alrite',
#   'girl',
#   'know',
#   'gail',
#   'is',
#   'neva',
#   'wrong',
#   'take',
#   'care',
#   'sweet',
#   'and',
#   'don',
#   'worry',
#   'tr',
#   'hun',
#   'love',
#   'yaxxx'],
#  ['just',
#   'gettin',
#   'bit',
#   'arty',
#   'with',
#   'my',
#   'collages',
#   'at',
#   'the',
#   'mo',
#   'well',
#   'tryin',
#   'ne',
#   'way',
#   'got',
#   'roast',
#   'in',
#   'min',
#   'lovely',
#   'shall',
#   'enjoy',
#   'that'],
#  ['sorry', 'll', 'call', 'later'],
#  ['aight',
#   'sorry',
#   'take',
#   'ten',
#   'years',
#   'to',
#   'shower',
#   'what',
#   'the',
#   'plan'],
#  ['so', 'when', 'do', 'you', 'wanna', 'gym', 'harri'],
#  ['ela', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['aight', 'tomorrow', 'around', 'lt', 'gt', 'it', 'is'],
#  ['not',
#   'enufcredeit',
#   'tocall',
#   'shall',
#   'ileave',
#   'uni',
#   'at',
#   'get',
#   'bus',
#   'to',
#   'yor',
#   'house'],
#  ['house',
#   'maid',
#   'is',
#   'the',
#   'murderer',
#   'coz',
#   'the',
#   'man',
#   'was',
#   'murdered',
#   'on',
#   'lt',
#   'gt',
#   'th',
#   'january',
#   'as',
#   'public',
#   'holiday',
#   'all',
#   'govt',
#   'instituitions',
#   'are',
#   'closed',
#   'including',
#   'post',
#   'office'],
#  ['lol',
#   'well',
#   'don',
#   'do',
#   'it',
#   'without',
#   'me',
#   'we',
#   'could',
#   'have',
#   'big',
#   'sale',
#   'together'],
#  ['jus', 'finish', 'watching', 'tv'],
#  ['dont', 'thnk', 'its', 'wrong', 'calling', 'between', 'us'],
#  ['you', 'call', 'him', 'now', 'ok', 'said', 'call', 'him'],
#  ['he', 'is', 'world', 'famamus'],
#  ['cant', 'try', 'new', 'invention', 'to', 'fly', 'not', 'joking'],
#  ['why', 'are', 'up', 'so', 'early'],
#  ['oh', 'all', 'have', 'to', 'come', 'ah'],
#  ['how', 'come'],
#  ['why', 'you', 'keeping', 'me', 'away', 'like', 'this'],
#  ['hope', 'you', 'are', 'not', 'scared'],
#  ['am',
#   'going',
#   'to',
#   'take',
#   'bath',
#   'ill',
#   'place',
#   'the',
#   'key',
#   'in',
#   'window'],
#  ['can',
#   'win',
#   'of',
#   'music',
#   'gift',
#   'vouchers',
#   'every',
#   'week',
#   'starting',
#   'now',
#   'txt',
#   'the',
#   'word',
#   'draw',
#   'to',
#   'tscs',
#   'www',
#   'ldew',
#   'com',
#   'skillgame',
#   'winaweek',
#   'age'],
#  ['ic', 'lol', 'should', 'play', 'doors', 'sometime', 'yo'],
#  ['that',
#   'sucks',
#   'll',
#   'go',
#   'over',
#   'so',
#   'can',
#   'do',
#   'my',
#   'hair',
#   'you',
#   'll',
#   'do',
#   'it',
#   'free',
#   'right'],
#  ['watching', 'tv', 'lor'],
#  ['too',
#   'much',
#   'close',
#   'to',
#   'my',
#   'heart',
#   'if',
#   'go',
#   'away',
#   'will',
#   'be',
#   'shattered',
#   'plz',
#   'stay',
#   'with',
#   'me'],
#  ['join',
#   'the',
#   'uk',
#   'horniest',
#   'dogging',
#   'service',
#   'and',
#   'can',
#   'have',
#   'sex',
#   'nite',
#   'just',
#   'sign',
#   'up',
#   'and',
#   'follow',
#   'the',
#   'instructions',
#   'txt',
#   'entry',
#   'to',
#   'now',
#   'nyt',
#   'ec',
#   'lp',
#   'msg'],
#  ['do',
#   'well',
#   'all',
#   'will',
#   'for',
#   'little',
#   'time',
#   'thing',
#   'of',
#   'good',
#   'times',
#   'ahead'],
#  ['that',
#   'day',
#   'say',
#   'cut',
#   'ur',
#   'hair',
#   'at',
#   'paragon',
#   'is',
#   'it',
#   'called',
#   'hair',
#   'sense',
#   'do',
#   'noe',
#   'how',
#   'much',
#   'is',
#   'hair',
#   'cut'],
#  ['welcome',
#   'to',
#   'select',
#   'an',
#   'service',
#   'with',
#   'added',
#   'benefits',
#   'you',
#   'can',
#   'now',
#   'call',
#   'our',
#   'specially',
#   'trained',
#   'advisors',
#   'free',
#   'from',
#   'your',
#   'mobile',
#   'by',
#   'dialling'],
#  ['all',
#   'was',
#   'well',
#   'until',
#   'slightly',
#   'disastrous',
#   'class',
#   'this',
#   'pm',
#   'with',
#   'my',
#   'fav',
#   'darlings',
#   'hope',
#   'day',
#   'off',
#   'ok',
#   'coffee',
#   'wld',
#   'be',
#   'good',
#   'as',
#   'can',
#   'stay',
#   'late',
#   'tomorrow',
#   'same',
#   'time',
#   'place',
#   'as',
#   'always'],
#  ['yes', 'here', 'tv', 'is', 'always', 'available', 'in', 'work', 'place'],
#  ['ok',
#   'wont',
#   'call',
#   'or',
#   'disturb',
#   'any',
#   'one',
#   'know',
#   'all',
#   'are',
#   'avoiding',
#   'me',
#   'am',
#   'burden',
#   'for',
#   'all'],
#  ['yeah',
#   'do',
#   'don',
#   'stand',
#   'to',
#   'close',
#   'tho',
#   'you',
#   'll',
#   'catch',
#   'something'],
#  ['have',
#   'you',
#   'emigrated',
#   'or',
#   'something',
#   'ok',
#   'maybe',
#   'was',
#   'bit',
#   'hopeful'],
#  ['says',
#   'the',
#   'lt',
#   'gt',
#   'year',
#   'old',
#   'with',
#   'man',
#   'and',
#   'money',
#   'down',
#   'to',
#   'my',
#   'last',
#   'lt',
#   'gt',
#   'still',
#   'waiting',
#   'for',
#   'that',
#   'check'],
#  ['hello',
#   'yeah',
#   've',
#   'just',
#   'got',
#   'out',
#   'of',
#   'the',
#   'bath',
#   'and',
#   'need',
#   'to',
#   'do',
#   'my',
#   'hair',
#   'so',
#   'll',
#   'come',
#   'up',
#   'when',
#   'done',
#   'yeah'],
#  ['omg', 'how', 'did', 'know', 'what', 'ate'],
#  ['no',
#   'need',
#   'lar',
#   'go',
#   'engin',
#   'cos',
#   'my',
#   'sis',
#   'at',
#   'arts',
#   'today'],
#  ['hey',
#   'there',
#   'glad',
#   'better',
#   'now',
#   'hear',
#   'treated',
#   'urself',
#   'to',
#   'digi',
#   'cam',
#   'is',
#   'it',
#   'good',
#   'we',
#   'off',
#   'at',
#   'pm',
#   'have',
#   'fab',
#   'new',
#   'year',
#   'in',
#   'coupla',
#   'wks'],
#  ['sure',
#   'thing',
#   'big',
#   'man',
#   'have',
#   'hockey',
#   'elections',
#   'at',
#   'shouldn',
#   'go',
#   'on',
#   'longer',
#   'than',
#   'an',
#   'hour',
#   'though'],
#  ['sounds', 'great', 'are', 'you', 'home', 'now'],
#  ['oic',
#   'saw',
#   'him',
#   'too',
#   'but',
#   'tot',
#   'he',
#   'din',
#   'me',
#   'found',
#   'group',
#   'liao'],
#  ['urgent',
#   'please',
#   'call',
#   'from',
#   'landline',
#   'cash',
#   'or',
#   'holiday',
#   'await',
#   'collection',
#   'cs',
#   'sae',
#   'po',
#   'box',
#   'xy'],
#  ['pls', 'pls', 'find', 'out', 'from', 'aunt', 'nike'],
#  ['bloomberg',
#   'message',
#   'center',
#   'why',
#   'wait',
#   'apply',
#   'for',
#   'your',
#   'future',
#   'http',
#   'careers',
#   'bloomberg',
#   'com'],
#  ['you',
#   'said',
#   'to',
#   'me',
#   'before',
#   'went',
#   'back',
#   'to',
#   'bed',
#   'that',
#   'you',
#   'can',
#   'sleep',
#   'for',
#   'anything'],
#  ['did',
#   'you',
#   'catch',
#   'the',
#   'bus',
#   'are',
#   'you',
#   'frying',
#   'an',
#   'egg',
#   'did',
#   'you',
#   'make',
#   'tea',
#   'are',
#   'you',
#   'eating',
#   'your',
#   'mom',
#   'left',
#   'over',
#   'dinner',
#   'do',
#   'you',
#   'feel',
#   'my',
#   'love'],
#  ['sure',
#   'but',
#   'since',
#   'my',
#   'parents',
#   'will',
#   'be',
#   'working',
#   'on',
#   'tuesday',
#   'don',
#   'really',
#   'need',
#   'cover',
#   'story'],
#  ['yo', 'my', 'trip', 'got', 'postponed', 'you', 'still', 'stocked', 'up'],
#  ['shall', 'call', 'now', 'dear', 'having', 'food'],
#  ['heart',
#   'is',
#   'empty',
#   'without',
#   'love',
#   'mind',
#   'is',
#   'empty',
#   'without',
#   'wisdom',
#   'eyes',
#   'empty',
#   'without',
#   'dreams',
#   'amp',
#   'life',
#   'is',
#   'empty',
#   'without',
#   'frnds',
#   'so',
#   'alwys',
#   'be',
#   'in',
#   'touch',
#   'good',
#   'night',
#   'amp',
#   'sweet',
#   'dreams'],
#  ['to',
#   'the',
#   'wonderful',
#   'okors',
#   'have',
#   'great',
#   'month',
#   'we',
#   'cherish',
#   'you',
#   'guys',
#   'and',
#   'wish',
#   'you',
#   'well',
#   'each',
#   'day',
#   'mojibiola'],
#  ['would',
#   'you',
#   'like',
#   'to',
#   'see',
#   'my',
#   'xxx',
#   'pics',
#   'they',
#   'are',
#   'so',
#   'hot',
#   'they',
#   'were',
#   'nearly',
#   'banned',
#   'in',
#   'the',
#   'uk'],
#  ['how',
#   'about',
#   'getting',
#   'in',
#   'touch',
#   'with',
#   'folks',
#   'waiting',
#   'for',
#   'company',
#   'just',
#   'txt',
#   'back',
#   'your',
#   'name',
#   'and',
#   'age',
#   'to',
#   'opt',
#   'in',
#   'enjoy',
#   'the',
#   'community',
#   'sms'],
#  ['hi',
#   'mobile',
#   'no',
#   'lt',
#   'gt',
#   'has',
#   'added',
#   'you',
#   'in',
#   'their',
#   'contact',
#   'list',
#   'on',
#   'www',
#   'fullonsms',
#   'com',
#   'it',
#   'great',
#   'place',
#   'to',
#   'send',
#   'free',
#   'sms',
#   'to',
#   'people',
#   'for',
#   'more',
#   'visit',
#   'fullonsms',
#   'com'],
#  ['okie'],
#  ...]

# %%
x_test = X_test.tolist()
x_test
# Out:
# [['this',
#   'is',
#   'the',
#   'nd',
#   'time',
#   'we',
#   'have',
#   'tried',
#   'to',
#   'contact',
#   'have',
#   'won',
#   'the',
#   'prize',
#   'claim',
#   'is',
#   'easy',
#   'just',
#   'call',
#   'now',
#   'only',
#   'per',
#   'minute',
#   'bt',
#   'national',
#   'rate'],
#  ['sorry', 'in', 'meeting', 'll', 'call', 'later'],
#  ['if', 'you', 'home', 'then', 'come', 'down', 'within', 'min'],
#  ['we',
#   'know',
#   'someone',
#   'who',
#   'you',
#   'know',
#   'that',
#   'fancies',
#   'you',
#   'call',
#   'to',
#   'find',
#   'out',
#   'who',
#   'pobox',
#   'ls',
#   'hb'],
#  ['our',
#   'mobile',
#   'number',
#   'has',
#   'won',
#   'to',
#   'claim',
#   'calls',
#   'us',
#   'back',
#   'or',
#   'ring',
#   'the',
#   'claims',
#   'hot',
#   'line',
#   'on'],
#  ['talk',
#   'sexy',
#   'make',
#   'new',
#   'friends',
#   'or',
#   'fall',
#   'in',
#   'love',
#   'in',
#   'the',
#   'worlds',
#   'most',
#   'discreet',
#   'text',
#   'dating',
#   'service',
#   'just',
#   'text',
#   'vip',
#   'to',
#   'and',
#   'see',
#   'who',
#   'you',
#   'could',
#   'meet'],
#  ['yes',
#   'he',
#   'is',
#   'really',
#   'great',
#   'bhaji',
#   'told',
#   'kallis',
#   'best',
#   'cricketer',
#   'after',
#   'sachin',
#   'in',
#   'world',
#   'very',
#   'tough',
#   'to',
#   'get',
#   'out'],
#  ['sorry', 'll', 'call', 'later'],
#  ['siva', 'is', 'in', 'hostel', 'aha'],
#  ['ll', 'text', 'carlos', 'and', 'let', 'you', 'know', 'hang', 'on'],
#  ['don',
#   'know',
#   'and',
#   'don',
#   'know',
#   'me',
#   'send',
#   'chat',
#   'to',
#   'now',
#   'and',
#   'let',
#   'find',
#   'each',
#   'other',
#   'only',
#   'msg',
#   'rcvd',
#   'hg',
#   'suite',
#   'lands',
#   'row',
#   'hl',
#   'ldn',
#   'years',
#   'or',
#   'over'],
#  ['hi',
#   'its',
#   'kate',
#   'it',
#   'was',
#   'lovely',
#   'to',
#   'see',
#   'you',
#   'tonight',
#   'and',
#   'ill',
#   'phone',
#   'you',
#   'tomorrow',
#   'got',
#   'to',
#   'sing',
#   'and',
#   'guy',
#   'gave',
#   'me',
#   'his',
#   'card',
#   'xxx'],
#  ['what',
#   'to',
#   'think',
#   'no',
#   'one',
#   'saying',
#   'clearly',
#   'ok',
#   'leave',
#   'no',
#   'need',
#   'to',
#   'ask',
#   'her',
#   'will',
#   'go',
#   'if',
#   'she',
#   'come',
#   'or',
#   'not'],
#  ['so',
#   'li',
#   'hai',
#   'me',
#   'bored',
#   'now',
#   'da',
#   'lecturer',
#   'repeating',
#   'last',
#   'weeks',
#   'stuff',
#   'waste',
#   'time'],
#  ['slept', 'thinkthis', 'time', 'lt', 'gt', 'pm', 'is', 'not', 'dangerous'],
#  ['our',
#   'prasanth',
#   'ettans',
#   'mother',
#   'passed',
#   'away',
#   'last',
#   'night',
#   'just',
#   'pray',
#   'for',
#   'her',
#   'and',
#   'family'],
#  ['okie',
#   'but',
#   'scared',
#   'say',
#   'fat',
#   'then',
#   'dun',
#   'wan',
#   'me',
#   'already'],
#  ['course',
#   'it',
#   'yrs',
#   'just',
#   'so',
#   'her',
#   'messages',
#   'on',
#   'messenger',
#   'lik',
#   'you',
#   'sending',
#   'me'],
#  ['your', 'daily', 'text', 'from', 'me', 'favour', 'this', 'time'],
#  ['lemme', 'know', 'when', 'you', 're', 'here'],
#  ['camera',
#   'quite',
#   'good',
#   'mega',
#   'pixels',
#   'optical',
#   'and',
#   'digital',
#   'dooms',
#   'have',
#   'lovely',
#   'holiday',
#   'be',
#   'safe',
#   'and',
#   'hope',
#   'you',
#   'hav',
#   'good',
#   'journey',
#   'happy',
#   'new',
#   'year',
#   'to',
#   'you',
#   'both',
#   'see',
#   'you',
#   'in',
#   'couple',
#   'of',
#   'weeks'],
#  ['no', 'home', 'work', 'to', 'do', 'meh'],
#  ['ok', 'lor'],
#  ['am', 'not', 'having', 'her', 'number', 'sir'],
#  ['multiply',
#   'the',
#   'numbers',
#   'independently',
#   'and',
#   'count',
#   'decimal',
#   'points',
#   'then',
#   'for',
#   'the',
#   'division',
#   'push',
#   'the',
#   'decimal',
#   'places',
#   'like',
#   'showed',
#   'you'],
#  ['private',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'shows',
#   'un',
#   'redeemed',
#   'points',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['ma', 'fan'],
#  ['you',
#   'are',
#   'great',
#   'role',
#   'model',
#   'you',
#   'are',
#   'giving',
#   'so',
#   'much',
#   'and',
#   'really',
#   'wish',
#   'each',
#   'day',
#   'for',
#   'miracle',
#   'but',
#   'god',
#   'as',
#   'reason',
#   'for',
#   'everything',
#   'and',
#   'must',
#   'say',
#   'wish',
#   'knew',
#   'why',
#   'but',
#   'dont',
#   've',
#   'looked',
#   'up',
#   'to',
#   'you',
#   'since',
#   'was',
#   'young',
#   'and',
#   'still',
#   'do',
#   'have',
#   'great',
#   'day'],
#  ['can',
#   'you',
#   'pls',
#   'send',
#   'me',
#   'that',
#   'company',
#   'name',
#   'in',
#   'saibaba',
#   'colany'],
#  ['back', 'lemme', 'know', 'when', 'you', 're', 'ready'],
#  ['today',
#   'is',
#   'accept',
#   'day',
#   'accept',
#   'me',
#   'as',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'no',
#   'rply',
#   'means',
#   'enemy'],
#  ['hi', 'got', 'the', 'money', 'da'],
#  ['hi',
#   'sorry',
#   'missed',
#   'your',
#   'call',
#   'can',
#   'you',
#   'pls',
#   'call',
#   'back'],
#  ['double',
#   'mins',
#   'txts',
#   'on',
#   'orange',
#   'tariffs',
#   'latest',
#   'motorola',
#   'sonyericsson',
#   'nokia',
#   'with',
#   'bluetooth',
#   'free',
#   'call',
#   'mobileupd',
#   'on',
#   'or',
#   'call',
#   'optout',
#   'hf'],
#  ['what', 'makes', 'you', 'most', 'happy'],
#  ['btw',
#   'regarding',
#   'that',
#   'we',
#   'should',
#   'really',
#   'try',
#   'to',
#   'see',
#   'if',
#   'anyone',
#   'else',
#   'can',
#   'be',
#   'our',
#   'th',
#   'guy',
#   'before',
#   'we',
#   'commit',
#   'to',
#   'random',
#   'dude'],
#  ['thank'],
#  ['want',
#   'to',
#   'be',
#   'there',
#   'so',
#   'can',
#   'kiss',
#   'you',
#   'and',
#   'feel',
#   'you',
#   'next',
#   'to',
#   'me'],
#  ['am',
#   'thinking',
#   'of',
#   'going',
#   'down',
#   'to',
#   'reg',
#   'for',
#   'pract',
#   'lessons',
#   'flung',
#   'my',
#   'advance',
#   'haha',
#   'wat',
#   'time',
#   'going'],
#  ['me',
#   'babe',
#   'feel',
#   'the',
#   'same',
#   'lets',
#   'just',
#   'get',
#   'about',
#   'it',
#   'both',
#   'try',
#   'cheer',
#   'up',
#   'not',
#   'fit',
#   'soo',
#   'muchxxlove',
#   'locaxx'],
#  ['am', 'going', 'to', 'bed', 'now', 'prin'],
#  ['sorry', 'that', 'took', 'so', 'long', 'omw', 'now'],
#  ['oh', 'ok', 'wat', 'ur', 'email'],
#  ['stop',
#   'the',
#   'story',
#   've',
#   'told',
#   'him',
#   've',
#   'returned',
#   'it',
#   'and',
#   'he',
#   'saying',
#   'should',
#   'not',
#   're',
#   'order',
#   'it'],
#  ['double',
#   'mins',
#   'double',
#   'txt',
#   'price',
#   'linerental',
#   'on',
#   'latest',
#   'orange',
#   'bluetooth',
#   'mobiles',
#   'call',
#   'mobileupd',
#   'for',
#   'the',
#   'very',
#   'latest',
#   'offers',
#   'or',
#   'call',
#   'optout',
#   'lf'],
#  ['in',
#   'school',
#   'now',
#   'll',
#   'be',
#   'in',
#   'da',
#   'lab',
#   'doing',
#   'some',
#   'stuff',
#   'give',
#   'me',
#   'call',
#   'when',
#   'done'],
#  ['ok',
#   'that',
#   'would',
#   'lovely',
#   'if',
#   'sure',
#   'think',
#   'about',
#   'wot',
#   'want',
#   'to',
#   'do',
#   'drinkin',
#   'dancin',
#   'eatin',
#   'cinema',
#   'in',
#   'out',
#   'about',
#   'up',
#   'to',
#   'wot',
#   'about'],
#  ['its', 'ok', 'just', 'askd', 'did', 'knw', 'tht', 'no'],
#  ['guess',
#   'who',
#   'am',
#   'this',
#   'is',
#   'the',
#   'first',
#   'time',
#   'created',
#   'web',
#   'page',
#   'www',
#   'asjesus',
#   'com',
#   'read',
#   'all',
#   'wrote',
#   'waiting',
#   'for',
#   'your',
#   'opinions',
#   'want',
#   'to',
#   'be',
#   'your',
#   'friend'],
#  ['lol', 'now', 'after', 'that', 'hot', 'air', 'balloon'],
#  ['urgent',
#   'your',
#   'mobile',
#   'number',
#   'has',
#   'been',
#   'awarded',
#   'ukp',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'landline',
#   'claim',
#   'valid',
#   'hrs',
#   'only',
#   'ppm'],
#  ['hey', 'do', 'you', 'want', 'anything', 'to', 'buy'],
#  ['that',
#   'way',
#   'transport',
#   'is',
#   'less',
#   'problematic',
#   'than',
#   'on',
#   'sat',
#   'night',
#   'by',
#   'the',
#   'way',
#   'if',
#   'want',
#   'to',
#   'ask',
#   'to',
#   'join',
#   'my',
#   'bday',
#   'feel',
#   'free',
#   'but',
#   'need',
#   'to',
#   'know',
#   'definite',
#   'nos',
#   'as',
#   'booking',
#   'on',
#   'fri'],
#  ['dont', 'understand', 'your', 'message'],
#  ['not',
#   'lot',
#   'has',
#   'happened',
#   'here',
#   'feels',
#   'very',
#   'quiet',
#   'beth',
#   'is',
#   'at',
#   'her',
#   'aunts',
#   'and',
#   'charlie',
#   'is',
#   'working',
#   'lots',
#   'just',
#   'me',
#   'and',
#   'helen',
#   'in',
#   'at',
#   'the',
#   'mo',
#   'how',
#   'have',
#   'you',
#   'been'],
#  ['was', 'gonna', 'ask', 'you', 'lol', 'but', 'think', 'its', 'at'],
#  ['babe', 'love', 'you', 'covers', 'your', 'face', 'in', 'kisses'],
#  ['anything', 'lar'],
#  ['where', 'been', 'hiding', 'stranger'],
#  ['kay', 'since', 'we', 'are', 'out', 'already'],
#  ['whats',
#   'that',
#   'coming',
#   'over',
#   'the',
#   'hill',
#   'is',
#   'it',
#   'monster',
#   'hope',
#   'you',
#   'have',
#   'great',
#   'day',
#   'things',
#   'going',
#   'fine',
#   'here',
#   'busy',
#   'though'],
#  ['and',
#   'that',
#   'fine',
#   'got',
#   'enough',
#   'bud',
#   'to',
#   'last',
#   'most',
#   'of',
#   'the',
#   'night',
#   'at',
#   'least'],
#  ['yup',
#   'still',
#   'having',
#   'coffee',
#   'wif',
#   'my',
#   'frens',
#   'my',
#   'fren',
#   'drove',
#   'she',
#   'll',
#   'give',
#   'me',
#   'lift'],
#  ['just',
#   'forced',
#   'myself',
#   'to',
#   'eat',
#   'slice',
#   'really',
#   'not',
#   'hungry',
#   'tho',
#   'this',
#   'sucks',
#   'mark',
#   'is',
#   'getting',
#   'worried',
#   'he',
#   'knows',
#   'sick',
#   'when',
#   'turn',
#   'down',
#   'pizza',
#   'lol'],
#  ['th', 'of', 'july'],
#  ['you', 'still', 'coming', 'tonight'],
#  ['called',
#   'but',
#   'no',
#   'one',
#   'pick',
#   'up',
#   'phone',
#   'ask',
#   'both',
#   'of',
#   'them',
#   'already',
#   'they',
#   'said',
#   'ok'],
#  ['they',
#   'said',
#   'dun',
#   'haf',
#   'passport',
#   'or',
#   'smth',
#   'like',
#   'dat',
#   'or',
#   'juz',
#   'send',
#   'to',
#   'my',
#   'email',
#   'account'],
#  ['ambrith', 'madurai', 'met', 'in', 'arun', 'dha', 'marrge', 'remembr'],
#  ['don',
#   'quite',
#   'know',
#   'what',
#   'to',
#   'do',
#   'still',
#   'can',
#   'get',
#   'hold',
#   'of',
#   'anyone',
#   'cud',
#   'pick',
#   'you',
#   'up',
#   'bout',
#   'pm',
#   'and',
#   'we',
#   'can',
#   'see',
#   'if',
#   'they',
#   're',
#   'in',
#   'the',
#   'pub'],
#  ['prepare', 'to', 'be', 'pleasured'],
#  ['the',
#   'monthly',
#   'amount',
#   'is',
#   'not',
#   'that',
#   'terrible',
#   'and',
#   'you',
#   'will',
#   'not',
#   'pay',
#   'anything',
#   'till',
#   'months',
#   'after',
#   'finishing',
#   'school'],
#  ['win',
#   'the',
#   'newest',
#   'harry',
#   'potter',
#   'and',
#   'the',
#   'order',
#   'of',
#   'the',
#   'phoenix',
#   'book',
#   'reply',
#   'harry',
#   'answer',
#   'questions',
#   'chance',
#   'to',
#   'be',
#   'the',
#   'first',
#   'among',
#   'readers'],
#  ['gonna',
#   'say',
#   'no',
#   'sorry',
#   'would',
#   'but',
#   'as',
#   'normal',
#   'am',
#   'starting',
#   'to',
#   'panic',
#   'about',
#   'time',
#   'sorry',
#   'again',
#   'are',
#   'you',
#   'seeing',
#   'on',
#   'tuesday'],
#  ['can',
#   'probably',
#   'come',
#   'by',
#   'everybody',
#   'done',
#   'around',
#   'lt',
#   'gt',
#   'right'],
#  ['hi',
#   'dear',
#   'call',
#   'me',
#   'its',
#   'urgnt',
#   'don',
#   'know',
#   'whats',
#   'your',
#   'problem',
#   'you',
#   'don',
#   'want',
#   'to',
#   'work',
#   'or',
#   'if',
#   'you',
#   'have',
#   'any',
#   'other',
#   'problem',
#   'at',
#   'least',
#   'tell',
#   'me',
#   'wating',
#   'for',
#   'your',
#   'reply'],
#  ['did', 'got', 'that', 'persons', 'story'],
#  ['thank', 'you', 'do', 'you', 'generally', 'date', 'the', 'brothas'],
#  ['oh', 'after', 'that', 'placement', 'there', 'ah'],
#  ['did', 'receive', 'my', 'msg'],
#  ['your',
#   'opinion',
#   'about',
#   'me',
#   'over',
#   'jada',
#   'kusruthi',
#   'lovable',
#   'silent',
#   'spl',
#   'character',
#   'not',
#   'matured',
#   'stylish',
#   'simple',
#   'pls',
#   'reply'],
#  ['did', 'he', 'just', 'say', 'somebody', 'is', 'named', 'tampa'],
#  ['ya',
#   'they',
#   'are',
#   'well',
#   'and',
#   'fine',
#   'bbd',
#   'pooja',
#   'full',
#   'pimples',
#   'even',
#   'she',
#   'become',
#   'quite',
#   'black',
#   'and',
#   'ur',
#   'rite',
#   'here',
#   'its',
#   'too',
#   'cold',
#   'wearing',
#   'sweatter'],
#  ['just', 'sleeping', 'and', 'surfing'],
#  ['if',
#   'he',
#   'started',
#   'searching',
#   'he',
#   'will',
#   'get',
#   'job',
#   'in',
#   'few',
#   'days',
#   'he',
#   'have',
#   'great',
#   'potential',
#   'and',
#   'talent'],
#  ['if', 'you', 're', 'thinking', 'of', 'lifting', 'me', 'one', 'then', 'no'],
#  ['call',
#   'from',
#   'tells',
#   'call',
#   'to',
#   'claim',
#   'prize',
#   'have',
#   'enter',
#   'all',
#   'ur',
#   'mobile',
#   'personal',
#   'details',
#   'the',
#   'prompts',
#   'careful'],
#  ['aww',
#   'you',
#   'must',
#   'be',
#   'nearly',
#   'dead',
#   'well',
#   'jez',
#   'iscoming',
#   'over',
#   'todo',
#   'some',
#   'workand',
#   'that',
#   'whilltake',
#   'forever'],
#  ['rt',
#   'king',
#   'pro',
#   'video',
#   'club',
#   'need',
#   'help',
#   'info',
#   'ringtoneking',
#   'co',
#   'uk',
#   'or',
#   'call',
#   'you',
#   'must',
#   'be',
#   'club',
#   'credits',
#   'redeemable',
#   'at',
#   'www',
#   'ringtoneking',
#   'co',
#   'uk',
#   'enjoy'],
#  ['you', 'got', 'called', 'tool'],
#  ['log', 'off', 'wat', 'it', 'sdryb'],
#  ['in', 'meeting', 'call', 'me', 'later', 'at'],
#  ['it', 'means', 'could', 'not', 'keep', 'ur', 'words'],
#  ['text',
#   'get',
#   'more',
#   'ringtones',
#   'logos',
#   'and',
#   'games',
#   'from',
#   'www',
#   'txt',
#   'com',
#   'questions',
#   'info',
#   'txt',
#   'co',
#   'uk'],
#  ['valentines',
#   'day',
#   'special',
#   'win',
#   'over',
#   'in',
#   'our',
#   'quiz',
#   'and',
#   'take',
#   'your',
#   'partner',
#   'on',
#   'the',
#   'trip',
#   'of',
#   'lifetime',
#   'send',
#   'go',
#   'to',
#   'now',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['no', 'message', 'no', 'responce', 'what', 'happend'],
#  ['so', 'wat', 'da', 'decision'],
#  ['your',
#   'account',
#   'for',
#   'xxxxxxxxx',
#   'shows',
#   'unredeemed',
#   'points',
#   'to',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'xxxxx',
#   'expires'],
#  ['ok',
#   'lor',
#   'ned',
#   'go',
#   'toa',
#   'payoh',
#   'while',
#   'return',
#   'smth',
#   'wan',
#   'send',
#   'me',
#   'there',
#   'or',
#   'wat'],
#  ['ho', 'ho', 'big', 'belly', 'laugh', 'see', 'ya', 'tomo'],
#  ['boltblue',
#   'tones',
#   'for',
#   'reply',
#   'poly',
#   'or',
#   'mono',
#   'eg',
#   'poly',
#   'cha',
#   'cha',
#   'slide',
#   'yeah',
#   'slow',
#   'jamz',
#   'toxic',
#   'come',
#   'with',
#   'me',
#   'or',
#   'stop',
#   'more',
#   'tones',
#   'txt',
#   'more'],
#  ['does',
#   'she',
#   'usually',
#   'take',
#   'fifteen',
#   'fucking',
#   'minutes',
#   'to',
#   'respond',
#   'to',
#   'yes',
#   'or',
#   'no',
#   'question'],
#  ['have', 'you', 'seen', 'who', 'back', 'at', 'holby'],
#  ['do',
#   'you',
#   'want',
#   'new',
#   'nokia',
#   'colour',
#   'phone',
#   'with',
#   'free',
#   'minutes',
#   'to',
#   'any',
#   'mobile',
#   'free',
#   'texts',
#   'free',
#   'camcorder',
#   'reply',
#   'or',
#   'call'],
#  ['yes',
#   'baby',
#   'we',
#   'can',
#   'study',
#   'all',
#   'the',
#   'positions',
#   'of',
#   'the',
#   'kama',
#   'sutra'],
#  ['here', 'yet', 'wearing', 'blue', 'shirt', 'black', 'pants'],
#  ['too'],
#  ['da', 'al', 'above', 'lt', 'gt'],
#  ['she',
#   'went',
#   'to',
#   'attend',
#   'another',
#   'two',
#   'rounds',
#   'today',
#   'but',
#   'still',
#   'did',
#   'reach',
#   'home'],
#  ['she', 'borderline', 'but', 'yeah', 'whatever'],
#  ['urgent',
#   'important',
#   'information',
#   'for',
#   'user',
#   'today',
#   'is',
#   'your',
#   'lucky',
#   'day',
#   'find',
#   'out',
#   'why',
#   'log',
#   'onto',
#   'http',
#   'www',
#   'urawinner',
#   'com',
#   'there',
#   'is',
#   'fantastic',
#   'surprise',
#   'awaiting',
#   'you'],
#  ['wat', 'would', 'like', 'ur', 'birthday'],
#  ['dont',
#   'think',
#   'you',
#   'need',
#   'yellow',
#   'card',
#   'for',
#   'uk',
#   'travel',
#   'ask',
#   'someone',
#   'that',
#   'has',
#   'gone',
#   'before',
#   'if',
#   'you',
#   'do',
#   'its',
#   'just',
#   'lt',
#   'gt',
#   'bucks'],
#  ['between', 'am', 'pm', 'cost'],
#  ['who', 'talking', 'about'],
#  ['tmr',
#   'timin',
#   'still',
#   'da',
#   'same',
#   'wat',
#   'cos',
#   'got',
#   'lesson',
#   'until'],
#  ['do',
#   'you',
#   'want',
#   'new',
#   'nokia',
#   'colour',
#   'phone',
#   'delivered',
#   'tomorrow',
#   'with',
#   'free',
#   'minutes',
#   'to',
#   'any',
#   'mobile',
#   'free',
#   'text',
#   'free',
#   'camcorder',
#   'reply',
#   'or',
#   'call'],
#  ['oh', 'icic', 'lor', 'den', 'meet', 'other', 'day'],
#  ['hey', 'are', 'you', 'angry', 'with', 'me', 'reply', 'me', 'dr'],
#  ['guess',
#   'what',
#   'somebody',
#   'you',
#   'know',
#   'secretly',
#   'fancies',
#   'you',
#   'wanna',
#   'find',
#   'out',
#   'who',
#   'it',
#   'is',
#   'give',
#   'us',
#   'call',
#   'on',
#   'from',
#   'landline',
#   'datebox',
#   'essexcm',
#   'xn',
#   'min'],
#  ['done', 'oredi'],
#  ['yup', 'no', 'need', 'll', 'jus', 'wait', 'rain', 'stop'],
#  ['thank', 'god', 'they', 'are', 'in', 'bed'],
#  ['as',
#   'per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'has',
#   'been',
#   'set',
#   'as',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'callers',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friends',
#   'callertune'],
#  ['tell',
#   'them',
#   'no',
#   'need',
#   'to',
#   'investigate',
#   'about',
#   'me',
#   'anywhere'],
#  ['shall', 'start', 'from', 'hear'],
#  ['am',
#   'not',
#   'sure',
#   'about',
#   'night',
#   'menu',
#   'know',
#   'only',
#   'about',
#   'noon',
#   'menu'],
#  ['company',
#   'is',
#   'very',
#   'good',
#   'environment',
#   'is',
#   'terrific',
#   'and',
#   'food',
#   'is',
#   'really',
#   'nice'],
#  ['will', 'be', 'outside', 'office', 'take', 'all', 'from', 'there'],
#  ['hot',
#   'live',
#   'fantasies',
#   'call',
#   'now',
#   'just',
#   'per',
#   'min',
#   'ntt',
#   'ltd',
#   'po',
#   'box',
#   'croydon',
#   'cr',
#   'wb',
#   'is',
#   'national',
#   'rate',
#   'call'],
#  ['ya',
#   'ok',
#   'vikky',
#   'vl',
#   'witin',
#   'lt',
#   'gt',
#   'mins',
#   'and',
#   'il',
#   'reply'],
#  ['tell', 'rob', 'to', 'mack', 'his', 'gf', 'in', 'the', 'theater'],
#  ['she', 'doesnt', 'need', 'any', 'test'],
#  ['fuck',
#   'cedar',
#   'key',
#   'and',
#   'fuck',
#   'her',
#   'come',
#   'over',
#   'anyway',
#   'tho'],
#  ['noice', 'text', 'me', 'when', 'you', 're', 'here'],
#  ['hey',
#   'will',
#   'be',
#   'really',
#   'pretty',
#   'late',
#   'you',
#   'want',
#   'to',
#   'go',
#   'for',
#   'the',
#   'lesson',
#   'first',
#   'will',
#   'join',
#   'you',
#   'only',
#   'reaching',
#   'tp',
#   'mrt'],
#  ['hi',
#   'this',
#   'is',
#   'mandy',
#   'sullivan',
#   'calling',
#   'from',
#   'hotmix',
#   'fm',
#   'you',
#   'are',
#   'chosen',
#   'to',
#   'receive',
#   'in',
#   'our',
#   'easter',
#   'prize',
#   'draw',
#   'please',
#   'telephone',
#   'to',
#   'claim',
#   'before',
#   'or',
#   'your',
#   'prize',
#   'will',
#   'be',
#   'transferred',
#   'to',
#   'someone',
#   'else'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'todays',
#   'draw',
#   'shows',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hrs',
#   'only'],
#  ['no', 'did', 'you', 'multimedia', 'message', 'them', 'or', 'mail'],
#  ['ok', 'lor', 'wat', 'time', 'finish'],
#  ['if', 'we', 'win', 'its', 'really', 'no', 'side', 'for', 'long', 'time'],
#  ['tell', 'me', 'whos', 'this', 'pls'],
#  ['thanx',
#   'yup',
#   'we',
#   'coming',
#   'back',
#   'on',
#   'sun',
#   'finish',
#   'dinner',
#   'going',
#   'back',
#   'hotel',
#   'now',
#   'time',
#   'flies',
#   'we',
#   're',
#   'tog',
#   'exactly',
#   'mth',
#   'today',
#   'hope',
#   'we',
#   'll',
#   'haf',
#   'many',
#   'more',
#   'mths',
#   'to',
#   'come'],
#  ['liked', 'your', 'new', 'house'],
#  ['sorry',
#   'im',
#   'getting',
#   'up',
#   'now',
#   'feel',
#   'really',
#   'bad',
#   'totally',
#   'rejected',
#   'that',
#   'kinda',
#   'me',
#   'thing'],
#  ['jus', 'finish', 'blowing', 'my', 'hair', 'finish', 'dinner', 'already'],
#  ['pity',
#   'was',
#   'in',
#   'mood',
#   'for',
#   'that',
#   'so',
#   'any',
#   'other',
#   'suggestions'],
#  ['then', 'dun', 'wear', 'jeans', 'lor'],
#  ['want', 'to', 'be', 'inside', 'you', 'every', 'night'],
#  ['hows',
#   'the',
#   'street',
#   'where',
#   'the',
#   'end',
#   'of',
#   'library',
#   'walk',
#   'is'],
#  ['where', 'we', 'meeting'],
#  ['so', 'when', 'do', 'you', 'wanna', 'gym'],
#  ['shop',
#   'till',
#   'drop',
#   'is',
#   'it',
#   'you',
#   'either',
#   'cash',
#   'or',
#   'travel',
#   'voucher',
#   'call',
#   'now',
#   'ntt',
#   'po',
#   'box',
#   'cr',
#   'bt',
#   'fixedline',
#   'cost',
#   'ppm',
#   'mobile',
#   'vary'],
#  ['probably',
#   'won',
#   'eat',
#   'at',
#   'all',
#   'today',
#   'think',
#   'gonna',
#   'pop',
#   'how',
#   'was',
#   'your',
#   'weekend',
#   'did',
#   'miss',
#   'me'],
#  ['helloooo',
#   'wake',
#   'up',
#   'sweet',
#   'morning',
#   'welcomes',
#   'you',
#   'enjoy',
#   'this',
#   'day',
#   'with',
#   'full',
#   'of',
#   'joy',
#   'gud',
#   'mrng'],
#  ['why',
#   'must',
#   'we',
#   'sit',
#   'around',
#   'and',
#   'wait',
#   'for',
#   'summer',
#   'days',
#   'to',
#   'celebrate',
#   'such',
#   'magical',
#   'sight',
#   'when',
#   'the',
#   'worlds',
#   'dressed',
#   'in',
#   'white',
#   'oooooh',
#   'let',
#   'there',
#   'be',
#   'snow'],
#  ['dear', 'good', 'morning', 'how', 'you', 'feeling', 'dear'],
#  ['no', 'jst', 'change', 'tat', 'only'],
#  ['tell',
#   'dear',
#   'what',
#   'happen',
#   'to',
#   'you',
#   'why',
#   'you',
#   'talking',
#   'to',
#   'me',
#   'like',
#   'an',
#   'alian'],
#  ['love', 'my', 'little', 'pocy', 'bell', 'am', 'sorry', 'but', 'love'],
#  ['our',
#   'dating',
#   'service',
#   'has',
#   'been',
#   'asked',
#   'contact',
#   'by',
#   'someone',
#   'shy',
#   'call',
#   'now',
#   'all',
#   'will',
#   'be',
#   'revealed',
#   'pobox',
#   'uz'],
#  ['yar',
#   'lor',
#   'actually',
#   'we',
#   'quite',
#   'fast',
#   'cos',
#   'da',
#   'ge',
#   'slow',
#   'wat',
#   'haha'],
#  ['we',
#   'are',
#   'at',
#   'grandmas',
#   'oh',
#   'dear',
#   'still',
#   'ill',
#   'felt',
#   'shit',
#   'this',
#   'morning',
#   'but',
#   'think',
#   'am',
#   'just',
#   'hungover',
#   'another',
#   'night',
#   'then',
#   'we',
#   'leave',
#   'on',
#   'sat'],
#  ['what', 'hello', 'wats', 'talks', 'email', 'address'],
#  ['private',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'shows',
#   'un',
#   'redeemed',
#   'points',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['ur',
#   'balance',
#   'is',
#   'now',
#   'ur',
#   'next',
#   'question',
#   'is',
#   'who',
#   'sang',
#   'uptown',
#   'girl',
#   'in',
#   'the',
#   'answer',
#   'txt',
#   'ur',
#   'answer',
#   'to',
#   'good',
#   'luck'],
#  ['couldn',
#   'say',
#   'no',
#   'as',
#   'he',
#   'is',
#   'dying',
#   'man',
#   'and',
#   'feel',
#   'sad',
#   'for',
#   'him',
#   'so',
#   'will',
#   'go',
#   'and',
#   'just',
#   'wanted',
#   'you',
#   'to',
#   'know',
#   'would',
#   'probably',
#   'be',
#   'gone',
#   'late',
#   'into',
#   'your',
#   'night'],
#  ['celebrate', 'my', 'day', 'else'],
#  ['tonight', 'yeah', 'be', 'down', 'for', 'that'],
#  ['only',
#   'saturday',
#   'and',
#   'sunday',
#   'holiday',
#   'so',
#   'its',
#   'very',
#   'difficult'],
#  ['what', 'you', 'need', 'you', 'have', 'person', 'to', 'give', 'na'],
#  ['hope',
#   'you',
#   'arnt',
#   'pissed',
#   'off',
#   'but',
#   'id',
#   'would',
#   'really',
#   'like',
#   'to',
#   'see',
#   'you',
#   'tomorrow',
#   'love',
#   'me',
#   'xxxxxxxxxxxxxx'],
#  ['aight',
#   'let',
#   'me',
#   'know',
#   'when',
#   'you',
#   're',
#   'gonna',
#   'be',
#   'around',
#   'usf'],
#  ['refused',
#   'loan',
#   'secured',
#   'or',
#   'unsecured',
#   'can',
#   'get',
#   'credit',
#   'call',
#   'free',
#   'now',
#   'or',
#   'text',
#   'back',
#   'help',
#   'we',
#   'will'],
#  ['good',
#   'morning',
#   'my',
#   'dear',
#   'have',
#   'great',
#   'amp',
#   'successful',
#   'day'],
#  ['dear',
#   'voucher',
#   'holder',
#   'to',
#   'claim',
#   'this',
#   'weeks',
#   'offer',
#   'at',
#   'your',
#   'pc',
#   'please',
#   'go',
#   'to',
#   'http',
#   'www',
#   'wtlp',
#   'co',
#   'uk',
#   'text',
#   'ts',
#   'cs',
#   'apply'],
#  ['understand',
#   'his',
#   'loss',
#   'is',
#   'my',
#   'gain',
#   'so',
#   'do',
#   'you',
#   'work',
#   'school'],
#  ['then',
#   'better',
#   'go',
#   'sleep',
#   'dun',
#   'disturb',
#   'liao',
#   'wake',
#   'up',
#   'then',
#   'msg',
#   'me',
#   'lor'],
#  ['new',
#   'textbuddy',
#   'chat',
#   'horny',
#   'guys',
#   'in',
#   'ur',
#   'area',
#   'just',
#   'free',
#   'receive',
#   'search',
#   'postcode',
#   'or',
#   'at',
#   'gaytextbuddy',
#   'com',
#   'txt',
#   'one',
#   'name',
#   'to'],
#  ['thought',
#   'praps',
#   'you',
#   'meant',
#   'another',
#   'one',
#   'goodo',
#   'll',
#   'look',
#   'tomorrow'],
#  ['dun',
#   'cut',
#   'too',
#   'short',
#   'leh',
#   'dun',
#   'like',
#   'ah',
#   'she',
#   'failed',
#   'she',
#   'quite',
#   'sad'],
#  ['bot', 'notes', 'oredi', 'cos', 'juz', 'rem', 'got'],
#  ['do',
#   'konw',
#   'waht',
#   'is',
#   'rael',
#   'friendship',
#   'im',
#   'gving',
#   'yuo',
#   'an',
#   'exmpel',
#   'jsut',
#   'ese',
#   'tihs',
#   'msg',
#   'evrey',
#   'splleing',
#   'of',
#   'tihs',
#   'msg',
#   'is',
#   'wrnog',
#   'bt',
#   'sitll',
#   'yuo',
#   'can',
#   'raed',
#   'it',
#   'wihtuot',
#   'ayn',
#   'mitsake',
#   'goodnight',
#   'amp',
#   'have',
#   'nice',
#   'sleep',
#   'sweet',
#   'dreams'],
#  ['no', 'dont', 'want', 'to', 'hear', 'anything'],
#  ['lol', 'where', 'do', 'come', 'up', 'with', 'these', 'ideas'],
#  ['kind',
#   'of',
#   'took',
#   'it',
#   'to',
#   'garage',
#   'centre',
#   'part',
#   'of',
#   'exhaust',
#   'needs',
#   'replacing',
#   'part',
#   'ordered',
#   'taking',
#   'it',
#   'to',
#   'be',
#   'fixed',
#   'tomo',
#   'morning'],
#  ['cant',
#   'think',
#   'of',
#   'anyone',
#   'with',
#   'spare',
#   'room',
#   'off',
#   'top',
#   'of',
#   'my',
#   'head'],
#  ['abeg',
#   'make',
#   'profit',
#   'but',
#   'its',
#   'start',
#   'are',
#   'you',
#   'using',
#   'it',
#   'to',
#   'get',
#   'sponsors',
#   'for',
#   'the',
#   'next',
#   'event'],
#  ['free',
#   'for',
#   'st',
#   'week',
#   'no',
#   'nokia',
#   'tone',
#   'ur',
#   'mobile',
#   'every',
#   'week',
#   'just',
#   'txt',
#   'nokia',
#   'to',
#   'get',
#   'txting',
#   'and',
#   'tell',
#   'ur',
#   'mates',
#   'www',
#   'getzed',
#   'co',
#   'uk',
#   'pobox',
#   'wq',
#   'norm',
#   'tone'],
#  ['dear', 'will', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['not', 'she', 'lip', 'synced', 'with', 'shangela'],
#  ['sorry',
#   'sent',
#   'blank',
#   'msg',
#   'again',
#   'yup',
#   'but',
#   'trying',
#   'do',
#   'some',
#   'serious',
#   'studying',
#   'now'],
#  ['tired', 'haven', 'slept', 'well', 'the', 'past', 'few', 'nights'],
#  ['hmmm',
#   'but',
#   'want',
#   'to',
#   'change',
#   'the',
#   'field',
#   'quickly',
#   'da',
#   'wanna',
#   'get',
#   'system',
#   'administrator',
#   'or',
#   'network',
#   'administrator'],
#  ['mmm', 'fuck', 'merry', 'christmas', 'to', 'me'],
#  ['home',
#   'doc',
#   'gave',
#   'me',
#   'pain',
#   'meds',
#   'says',
#   'everything',
#   'is',
#   'fine'],
#  ['dun', 'wan', 'to', 'watch', 'infernal', 'affair'],
#  ['thursday',
#   'night',
#   'yeah',
#   'sure',
#   'thing',
#   'we',
#   'll',
#   'work',
#   'it',
#   'out',
#   'then'],
#  ['have',
#   'had',
#   'two',
#   'more',
#   'letters',
#   'from',
#   'will',
#   'copy',
#   'them',
#   'for',
#   'you',
#   'cos',
#   'one',
#   'has',
#   'message',
#   'for',
#   'you',
#   'speak',
#   'soon'],
#  ['from',
#   'next',
#   'month',
#   'get',
#   'upto',
#   'more',
#   'calls',
#   'ur',
#   'standard',
#   'network',
#   'charge',
#   'activate',
#   'call',
#   'wire',
#   'net',
#   'st',
#   'terms',
#   'pobox',
#   'uz',
#   'cost',
#   'min',
#   'mobcudb',
#   'more'],
#  ['it',
#   'didnt',
#   'work',
#   'again',
#   'oh',
#   'ok',
#   'goodnight',
#   'then',
#   'll',
#   'fix',
#   'and',
#   'have',
#   'it',
#   'ready',
#   'by',
#   'the',
#   'time',
#   'you',
#   'wake',
#   'up',
#   'you',
#   'are',
#   'very',
#   'dearly',
#   'missed',
#   'have',
#   'good',
#   'night',
#   'sleep'],
#  ['too',
#   'late',
#   'said',
#   'have',
#   'the',
#   'website',
#   'didn',
#   'have',
#   'or',
#   'dont',
#   'have',
#   'the',
#   'slippers'],
#  ['in',
#   'other',
#   'news',
#   'after',
#   'hassling',
#   'me',
#   'to',
#   'get',
#   'him',
#   'weed',
#   'for',
#   'week',
#   'andres',
#   'has',
#   'no',
#   'money'],
#  ['skint',
#   'too',
#   'but',
#   'fancied',
#   'few',
#   'bevies',
#   'waz',
#   'gona',
#   'go',
#   'meet',
#   'othrs',
#   'in',
#   'spoon',
#   'but',
#   'jst',
#   'bin',
#   'watchng',
#   'planet',
#   'earth',
#   'sofa',
#   'is',
#   'comfey',
#   'if',
#   'dont',
#   'make',
#   'it',
#   'hav',
#   'gd',
#   'night'],
#  ['keep', 'my', 'payasam', 'there', 'if', 'rinu', 'brings'],
#  ['tick',
#   'tick',
#   'tick',
#   'where',
#   'are',
#   'you',
#   'could',
#   'die',
#   'of',
#   'loneliness',
#   'you',
#   'know',
#   'pouts',
#   'stomps',
#   'feet',
#   'need',
#   'you'],
#  ['finally',
#   'it',
#   'has',
#   'happened',
#   'aftr',
#   'decades',
#   'beer',
#   'is',
#   'now',
#   'cheaper',
#   'than',
#   'petrol',
#   'the',
#   'goverment',
#   'expects',
#   'us',
#   'to',
#   'drink',
#   'but',
#   'don',
#   'drive'],
#  ['so', 'how', 'the', 'weather', 'over', 'there'],
#  ['do', 'you', 'know', 'when', 'the', 'result'],
#  ['you', 'do', 'what', 'all', 'you', 'like'],
#  ['take', 'care', 'get', 'well', 'soon'],
#  ['you', 'still', 'around', 'could', 'use', 'half', 'th'],
#  ['single',
#   'line',
#   'with',
#   'big',
#   'meaning',
#   'miss',
#   'anything',
#   'ur',
#   'best',
#   'life',
#   'but',
#   'don',
#   'miss',
#   'ur',
#   'best',
#   'life',
#   'for',
#   'anything',
#   'gud',
#   'nyt'],
#  ['there',
#   'is',
#   'os',
#   'called',
#   'ubandu',
#   'which',
#   'will',
#   'run',
#   'without',
#   'installing',
#   'in',
#   'hard',
#   'disk',
#   'you',
#   'can',
#   'use',
#   'that',
#   'os',
#   'to',
#   'copy',
#   'the',
#   'important',
#   'files',
#   'in',
#   'system',
#   'and',
#   'give',
#   'it',
#   'to',
#   'repair',
#   'shop'],
#  ['wow', 'impressed', 'have', 'funs', 'shopping'],
#  ['what', 'today', 'sunday', 'sunday', 'is', 'holiday', 'so', 'no', 'work'],
#  ['that',
#   'fine',
#   'have',
#   'him',
#   'give',
#   'me',
#   'call',
#   'if',
#   'he',
#   'knows',
#   'what',
#   'he',
#   'wants',
#   'or',
#   'has',
#   'any',
#   'questions'],
#  ['have', 'to', 'take', 'exam', 'with', 'march'],
#  ['ok',
#   'good',
#   'then',
#   'later',
#   'come',
#   'find',
#   'lucky',
#   'told',
#   'to',
#   'go',
#   'earlier',
#   'later',
#   'pple',
#   'take',
#   'finish',
#   'no',
#   'more',
#   'again'],
#  ['why', 'you', 'dint', 'come', 'with', 'us'],
#  ['free',
#   'polyphonic',
#   'ringtone',
#   'text',
#   'super',
#   'to',
#   'to',
#   'get',
#   'your',
#   'free',
#   'poly',
#   'tone',
#   'of',
#   'the',
#   'week',
#   'now',
#   'sn',
#   'pobox',
#   'nr',
#   'zs',
#   'subscription',
#   'pw'],
#  ['no', 'thank', 'you', 'you', 've', 'been', 'wonderful'],
#  ['babe', 'back', 'come', 'back', 'to', 'me'],
#  ['oh',
#   'ya',
#   'got',
#   'hip',
#   'hop',
#   'open',
#   'haha',
#   'was',
#   'thinking',
#   'can',
#   'go',
#   'for',
#   'jazz',
#   'then',
#   'zoom',
#   'to',
#   'cine',
#   'actually',
#   'tonight',
#   'free',
#   'leh',
#   'and',
#   'there',
#   'kb',
#   'lesson',
#   'tonight'],
#  ['my', 'battery', 'is', 'low', 'babe'],
#  ['it', 'ok', 'wun', 'angry', 'msg', 'aft', 'come', 'home', 'tonight'],
#  ['where', 'are', 'you', 'how', 'did', 'you', 'performed'],
#  ['http',
#   'tms',
#   'widelive',
#   'com',
#   'index',
#   'wml',
#   'id',
#   'ad',
#   'first',
#   'true',
#   'ringtone'],
#  ['burger',
#   'king',
#   'wanna',
#   'play',
#   'footy',
#   'at',
#   'top',
#   'stadium',
#   'get',
#   'burger',
#   'king',
#   'before',
#   'st',
#   'sept',
#   'and',
#   'go',
#   'large',
#   'or',
#   'super',
#   'with',
#   'coca',
#   'cola',
#   'and',
#   'walk',
#   'out',
#   'winner'],
#  ['wife', 'how', 'she', 'knew', 'the', 'time', 'of', 'murder', 'exactly'],
#  ['until', 'lor', 'ya', 'can', 'go', 'dinner', 'together'],
#  ['when', 'you', 'guys', 'planning', 'on', 'coming', 'over'],
#  ['sorry', 'sir', 'will', 'call', 'you', 'tomorrow', 'senthil', 'hsbc'],
#  ['that', 'what', 'love', 'to', 'hear', 'see', 'you', 'sundayish', 'then'],
#  ['wat', 'time', 'liao', 'where', 'still', 'got'],
#  ['aight',
#   've',
#   'been',
#   'set',
#   'free',
#   'think',
#   'you',
#   'could',
#   'text',
#   'me',
#   'blake',
#   'address',
#   'it',
#   'occurs',
#   'to',
#   'me',
#   'not',
#   'quite',
#   'as',
#   'sure',
#   'what',
#   'doing',
#   'as',
#   'thought',
#   'was'],
#  ['also',
#   'thk',
#   'too',
#   'fast',
#   'xy',
#   'suggest',
#   'one',
#   'not',
#   'me',
#   'dun',
#   'wan',
#   'it',
#   'ok',
#   'going',
#   'rain',
#   'leh',
#   'where',
#   'got',
#   'gd'],
#  ['themob',
#   'check',
#   'out',
#   'our',
#   'newest',
#   'selection',
#   'of',
#   'content',
#   'games',
#   'tones',
#   'gossip',
#   'babes',
#   'and',
#   'sport',
#   'keep',
#   'your',
#   'mobile',
#   'fit',
#   'and',
#   'funky',
#   'text',
#   'wap',
#   'to'],
#  ['alrite',
#   'jod',
#   'hows',
#   'the',
#   'revision',
#   'goin',
#   'keris',
#   'bin',
#   'doin',
#   'smidgin',
#   'way',
#   'wanna',
#   'cum',
#   'over',
#   'after',
#   'college',
#   'xx'],
#  ['busy',
#   'here',
#   'trying',
#   'to',
#   'finish',
#   'for',
#   'new',
#   'year',
#   'am',
#   'looking',
#   'forward',
#   'to',
#   'finally',
#   'meeting',
#   'you'],
#  ['the', 'new', 'deus', 'ex', 'game', 'comin', 'early', 'next', 'yr'],
#  ['boy', 'you', 'best', 'get', 'yo', 'ass', 'out', 'here', 'quick'],
#  ['update', 'your', 'face', 'book', 'status', 'frequently'],
#  ['sorry', 'not', 'free'],
#  ['wat',
#   'makes',
#   'thk',
#   'll',
#   'fall',
#   'down',
#   'but',
#   'actually',
#   'thk',
#   'quite',
#   'prone',
#   'falls',
#   'lucky',
#   'my',
#   'dad',
#   'at',
#   'home',
#   'ask',
#   'him',
#   'come',
#   'fetch',
#   'me',
#   'already'],
#  ['back',
#   'amp',
#   'we',
#   're',
#   'packing',
#   'the',
#   'car',
#   'now',
#   'll',
#   'let',
#   'you',
#   'know',
#   'if',
#   'there',
#   'room'],
#  ['dun',
#   'sad',
#   'it',
#   'over',
#   'dun',
#   'thk',
#   'abt',
#   'it',
#   'already',
#   'concentrate',
#   'on',
#   'ur',
#   'other',
#   'papers'],
#  ['for',
#   'real',
#   'tho',
#   'this',
#   'sucks',
#   'can',
#   'even',
#   'cook',
#   'my',
#   'whole',
#   'electricity',
#   'is',
#   'out',
#   'and',
#   'hungry'],
#  ['yo', 'any', 'way', 'we', 'could', 'pick', 'something', 'up', 'tonight'],
#  ['horrible',
#   'eat',
#   'macs',
#   'eat',
#   'until',
#   'forgot',
#   'abt',
#   'me',
#   'already',
#   'rite',
#   'take',
#   'so',
#   'long',
#   'reply',
#   'thk',
#   'it',
#   'more',
#   'toot',
#   'than',
#   'so',
#   'prepared',
#   'now',
#   'wat',
#   'shall',
#   'eat'],
#  ['oh',
#   'ho',
#   'is',
#   'this',
#   'the',
#   'first',
#   'time',
#   'use',
#   'these',
#   'type',
#   'of',
#   'words'],
#  ['good', 'evening', 'how', 'are', 'you'],
#  ['how', 'is', 'your', 'business', 'now'],
#  ['which', 'channel'],
#  ['hope',
#   'ur',
#   'head',
#   'doesn',
#   'hurt',
#   'much',
#   'am',
#   'ploughing',
#   'my',
#   'way',
#   'through',
#   'pile',
#   'of',
#   'ironing',
#   'staying',
#   'in',
#   'with',
#   'chinky',
#   'tonight',
#   'come',
#   'round',
#   'if',
#   'you',
#   'like'],
#  ['buy',
#   'space',
#   'invaders',
#   'chance',
#   'win',
#   'orig',
#   'arcade',
#   'game',
#   'console',
#   'press',
#   'for',
#   'games',
#   'arcade',
#   'std',
#   'wap',
#   'charge',
#   'see',
#   'co',
#   'uk',
#   'games',
#   'terms',
#   'settings',
#   'no',
#   'purchase'],
#  ['or', 'guess', 'lt', 'gt', 'min'],
#  ['let',
#   'pool',
#   'our',
#   'money',
#   'together',
#   'and',
#   'buy',
#   'bunch',
#   'of',
#   'lotto',
#   'tickets',
#   'if',
#   'we',
#   'win',
#   'get',
#   'lt',
#   'gt',
#   'get',
#   'lt',
#   'gt',
#   'deal'],
#  ['double',
#   'your',
#   'mins',
#   'txts',
#   'on',
#   'orange',
#   'or',
#   'price',
#   'linerental',
#   'motorola',
#   'and',
#   'sonyericsson',
#   'with',
#   'tooth',
#   'free',
#   'nokia',
#   'free',
#   'call',
#   'mobileupd',
#   'on',
#   'or',
#   'optout',
#   'hv'],
#  ['oh',
#   'my',
#   'love',
#   'it',
#   'soooo',
#   'good',
#   'to',
#   'hear',
#   'from',
#   'you',
#   'omg',
#   'missed',
#   'you',
#   'so',
#   'much',
#   'today',
#   'sorry',
#   'your',
#   'having',
#   'problems',
#   'with',
#   'the',
#   'provider',
#   'but',
#   'thank',
#   'you',
#   'for',
#   'tming',
#   'me'],
#  ['my', 'exam', 'is', 'for', 'february', 'wish', 'you', 'great', 'day'],
#  ['who',
#   'were',
#   'those',
#   'people',
#   'were',
#   'you',
#   'in',
#   'tour',
#   'thought',
#   'you',
#   'were',
#   'doing',
#   'that',
#   'sofa',
#   'thing',
#   'you',
#   'sent',
#   'me',
#   'your',
#   'curious',
#   'sugar'],
#  ['urgent',
#   'your',
#   'mobile',
#   'number',
#   'has',
#   'been',
#   'awarded',
#   'with',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hrs',
#   'only'],
#  ['his',
#   'frens',
#   'go',
#   'then',
#   'he',
#   'in',
#   'lor',
#   'not',
#   'alone',
#   'wif',
#   'my',
#   'mum',
#   'sis',
#   'lor'],
#  ['are', 'you', 'in', 'the', 'pub'],
#  ['hey',
#   'what',
#   'time',
#   'is',
#   'your',
#   'driving',
#   'on',
#   'fri',
#   'we',
#   'go',
#   'for',
#   'evaluation',
#   'on',
#   'fri'],
#  ['so', 'gd', 'got', 'free', 'ice', 'cream', 'oso', 'wan'],
#  ['thanks',
#   'for',
#   'your',
#   'ringtone',
#   'order',
#   'ref',
#   'number',
#   'your',
#   'mobile',
#   'will',
#   'be',
#   'charged',
#   'should',
#   'your',
#   'tone',
#   'not',
#   'arrive',
#   'please',
#   'call',
#   'customer',
#   'services',
#   'on'],
#  ['just',
#   'sent',
#   'it',
#   'so',
#   'what',
#   'type',
#   'of',
#   'food',
#   'do',
#   'you',
#   'like'],
#  ['tee', 'hee', 'off', 'to', 'lecture', 'cheery', 'bye', 'bye'],
#  ['private',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'shows',
#   'un',
#   'redeemed',
#   'points',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'this',
#   'week',
#   'in',
#   'our',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'to',
#   'now',
#   'cs',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['can', 'send', 'me', 'copy', 'of', 'da', 'report'],
#  ['future',
#   'is',
#   'not',
#   'what',
#   'we',
#   'planned',
#   'for',
#   'tomorrow',
#   'it',
#   'is',
#   'the',
#   'result',
#   'of',
#   'what',
#   'we',
#   'do',
#   'today',
#   'do',
#   'the',
#   'best',
#   'in',
#   'present',
#   'enjoy',
#   'the',
#   'future'],
#  ['no', 'da', 'today', 'also', 'forgot'],
#  ['stupid', 'auto', 'correct', 'on', 'my', 'phone'],
#  ['sorry',
#   'guess',
#   'whenever',
#   'can',
#   'get',
#   'hold',
#   'of',
#   'my',
#   'connections',
#   'maybe',
#   'an',
#   'hour',
#   'or',
#   'two',
#   'll',
#   'text',
#   'you'],
#  ['think',
#   'if',
#   'he',
#   'rule',
#   'tamilnadu',
#   'then',
#   'its',
#   'very',
#   'tough',
#   'for',
#   'our',
#   'people'],
#  ['you', 've', 'always', 'been', 'the', 'brainy', 'one'],
#  ['how', 'much', 'willing', 'to', 'pay'],
#  ['do', 'want', 'meet', 'up', 'morro'],
#  ['jus',
#   'telling',
#   'dat',
#   'll',
#   'leaving',
#   'shanghai',
#   'on',
#   'st',
#   'instead',
#   'so',
#   'we',
#   'll',
#   'haf',
#   'more',
#   'time',
#   'meet',
#   'up',
#   'cya'],
#  ['princess', 'is', 'your', 'kitty', 'shaved', 'or', 'natural'],
#  ['have', 'you', 'not', 'finished', 'work', 'yet', 'or', 'something'],
#  ['so',
#   'in',
#   'love',
#   'with',
#   'you',
#   'excited',
#   'each',
#   'day',
#   'spend',
#   'with',
#   'you',
#   'you',
#   'make',
#   'me',
#   'so',
#   'happy'],
#  ['and', 'half', 'years', 'missed', 'your', 'friendship'],
#  ['you',
#   'are',
#   'awarded',
#   'sipix',
#   'digital',
#   'camera',
#   'call',
#   'from',
#   'landline',
#   'delivery',
#   'within',
#   'days',
#   'cs',
#   'box',
#   'bp',
#   'yr',
#   'warranty',
#   'ppm'],
#  ['goin', 'out', 'nite'],
#  ['at', 'home', 'by', 'the', 'way'],
#  ['so', 'that', 'takes', 'away', 'some', 'money', 'worries'],
#  ['your',
#   'unique',
#   'user',
#   'id',
#   'is',
#   'for',
#   'removal',
#   'send',
#   'stop',
#   'to',
#   'customer',
#   'services'],
#  ['wanna',
#   'have',
#   'laugh',
#   'try',
#   'chit',
#   'chat',
#   'on',
#   'your',
#   'mobile',
#   'now',
#   'logon',
#   'by',
#   'txting',
#   'the',
#   'word',
#   'chat',
#   'and',
#   'send',
#   'it',
#   'to',
#   'no',
#   'cm',
#   'po',
#   'box',
#   'london',
#   'zf',
#   'msg',
#   'rcvd'],
#  ['am', 'in', 'your', 'office', 'na'],
#  ['nvm', 'take', 'ur', 'time'],
#  ['aight',
#   'you',
#   'close',
#   'by',
#   'or',
#   'still',
#   'down',
#   'around',
#   'alex',
#   'place'],
#  ['am',
#   'on',
#   'the',
#   'uworld',
#   'site',
#   'am',
#   'buying',
#   'the',
#   'qbank',
#   'only',
#   'or',
#   'am',
#   'buying',
#   'it',
#   'with',
#   'the',
#   'self',
#   'assessment',
#   'also'],
#  ['get',
#   'brand',
#   'new',
#   'mobile',
#   'phone',
#   'by',
#   'being',
#   'an',
#   'agent',
#   'of',
#   'the',
#   'mob',
#   'plus',
#   'loads',
#   'more',
#   'goodies',
#   'for',
#   'more',
#   'info',
#   'just',
#   'text',
#   'mat',
#   'to'],
#  ['you', 'have', 'new', 'message', 'call'],
#  ['fine', 'hope', 'you', 'are', 'also'],
#  ['lol',
#   'or',
#   'could',
#   'just',
#   'starve',
#   'and',
#   'lose',
#   'pound',
#   'by',
#   'the',
#   'end',
#   'of',
#   'the',
#   'day'],
#  ['wait', 'will', 'msg', 'after', 'lt', 'gt', 'min'],
#  ['are',
#   'you',
#   'sure',
#   'you',
#   'don',
#   'mean',
#   'get',
#   'here',
#   'we',
#   'made',
#   'you',
#   'hold',
#   'all',
#   'the',
#   'weed'],
#  ['tot', 'reach', 'liao', 'he', 'said', 'shirt'],
#  ['think', 've', 'fixed', 'it', 'can', 'you', 'send', 'test', 'message'],
#  ['no', 'problem', 'how', 'are', 'you', 'doing'],
#  ['what', 'you', 'doing', 'how', 'are', 'you'],
#  ['accordingly',
#   'repeat',
#   'just',
#   'text',
#   'the',
#   'word',
#   'ok',
#   'on',
#   'your',
#   'mobile',
#   'phone',
#   'and',
#   'send'],
#  ['argh', 'why', 'the', 'fuck', 'is', 'nobody', 'in', 'town'],
#  ['velly', 'good', 'yes', 'please'],
#  ['nt',
#   'only',
#   'for',
#   'driving',
#   'even',
#   'for',
#   'many',
#   'reasons',
#   'she',
#   'is',
#   'called',
#   'bbd',
#   'thts',
#   'it',
#   'chikku',
#   'then',
#   'hw',
#   'abt',
#   'dvg',
#   'cold',
#   'heard',
#   'tht',
#   'vinobanagar',
#   'violence',
#   'hw',
#   'is',
#   'the',
#   'condition',
#   'and',
#   'hw',
#   'ru',
#   'any',
#   'problem'],
#  ['double',
#   'mins',
#   'and',
#   'txts',
#   'months',
#   'free',
#   'bluetooth',
#   'on',
#   'orange',
#   'available',
#   'on',
#   'sony',
#   'nokia',
#   'motorola',
#   'phones',
#   'call',
#   'mobileupd',
#   'on',
#   'or',
#   'call',
#   'optout',
#   'dx'],
#  ['cant',
#   'keep',
#   'talking',
#   'to',
#   'people',
#   'if',
#   'am',
#   'not',
#   'sure',
#   'can',
#   'pay',
#   'them',
#   'if',
#   'they',
#   'agree',
#   'to',
#   'price',
#   'so',
#   'pls',
#   'tell',
#   'me',
#   'what',
#   'you',
#   'want',
#   'to',
#   'really',
#   'buy',
#   'and',
#   'how',
#   'much',
#   'you',
#   'are',
#   'willing',
#   'to',
#   'pay'],
#  ['there', 'bold', 'lt', 'gt', 'is', 'that', 'yours'],
#  ['thinking', 'of'],
#  ['sday', 'only', 'joined', 'so', 'training', 'we', 'started', 'today'],
#  ['wonders',
#   'in',
#   'my',
#   'world',
#   'th',
#   'you',
#   'th',
#   'ur',
#   'style',
#   'th',
#   'ur',
#   'smile',
#   'th',
#   'ur',
#   'personality',
#   'rd',
#   'ur',
#   'nature',
#   'nd',
#   'ur',
#   'sms',
#   'and',
#   'st',
#   'ur',
#   'lovely',
#   'friendship',
#   'good',
#   'morning',
#   'dear'],
#  ['haha', 'awesome', 'be', 'there', 'in', 'minute'],
#  ['may', 'approve', 'panalam', 'but', 'it', 'should', 'have', 'more', 'posts'],
#  ['so',
#   'now',
#   'my',
#   'dad',
#   'is',
#   'gonna',
#   'call',
#   'after',
#   'he',
#   'gets',
#   'out',
#   'of',
#   'work',
#   'and',
#   'ask',
#   'all',
#   'these',
#   'crazy',
#   'questions'],
#  ['splashmobile',
#   'choose',
#   'from',
#   'of',
#   'gr',
#   'tones',
#   'each',
#   'wk',
#   'this',
#   'is',
#   'subscrition',
#   'service',
#   'with',
#   'weekly',
#   'tones',
#   'costing',
#   'have',
#   'one',
#   'credit',
#   'kick',
#   'back',
#   'and',
#   'enjoy'],
#  ['come',
#   'around',
#   'lt',
#   'decimal',
#   'gt',
#   'pm',
#   'vikky',
#   'otside',
#   'nw',
#   'il',
#   'come',
#   'by',
#   'tht',
#   'time'],
#  ['yup',
#   'shd',
#   'haf',
#   'ard',
#   'pages',
#   'if',
#   'add',
#   'figures',
#   'all',
#   'got',
#   'how',
#   'many',
#   'pages'],
#  ['fantasy',
#   'football',
#   'is',
#   'back',
#   'on',
#   'your',
#   'tv',
#   'go',
#   'to',
#   'sky',
#   'gamestar',
#   'on',
#   'sky',
#   'active',
#   'and',
#   'play',
#   'dream',
#   'team',
#   'scoring',
#   'starts',
#   'on',
#   'saturday',
#   'so',
#   'register',
#   'now',
#   'sky',
#   'opt',
#   'out',
#   'to'],
#  ['dunno',
#   'leh',
#   'cant',
#   'remember',
#   'mayb',
#   'lor',
#   'so',
#   'wat',
#   'time',
#   'we',
#   'meeting',
#   'tmr'],
#  ['yeah', 'lol', 'luckily', 'didn', 'have', 'starring', 'role', 'like', 'you'],
#  ['hard',
#   'but',
#   'true',
#   'how',
#   'much',
#   'you',
#   'show',
#   'amp',
#   'express',
#   'your',
#   'love',
#   'to',
#   'someone',
#   'that',
#   'much',
#   'it',
#   'will',
#   'hurt',
#   'when',
#   'they',
#   'leave',
#   'you',
#   'or',
#   'you',
#   'get',
#   'seperated',
#   '〨ud',
#   'evening'],
#  ['good', 'have', 'you', 'registered', 'to', 'vote'],
#  ['ok',
#   'thats',
#   'cool',
#   'its',
#   'just',
#   'off',
#   'either',
#   'raglan',
#   'rd',
#   'or',
#   'edward',
#   'rd',
#   'behind',
#   'the',
#   'cricket',
#   'ground',
#   'gimme',
#   'ring',
#   'when',
#   'ur',
#   'closeby',
#   'see',
#   'you',
#   'tuesday'],
#  ['emailed', 'yifeng', 'my', 'part', 'oredi', 'can', 'get', 'it', 'fr', 'him'],
#  ['re',
#   'met',
#   'alex',
#   'nichols',
#   'from',
#   'middle',
#   'school',
#   'and',
#   'it',
#   'turns',
#   'out',
#   'he',
#   'dealing'],
#  ['ok', 'she', 'll', 'be', 'ok', 'guess'],
#  ['what', 'is', 'your', 'record', 'for', 'one', 'night'],
#  ['dont',
#   'have',
#   'any',
#   'of',
#   'your',
#   'file',
#   'in',
#   'my',
#   'bag',
#   'was',
#   'in',
#   'work',
#   'when',
#   'you',
#   'called',
#   'me',
#   'll',
#   'tell',
#   'you',
#   'if',
#   'find',
#   'anything',
#   'in',
#   'my',
#   'room'],
#  ['rofl', 'betta', 'invest', 'in', 'some', 'anti', 'aging', 'products'],
#  ['free',
#   'for',
#   'st',
#   'week',
#   'no',
#   'nokia',
#   'tone',
#   'ur',
#   'mobile',
#   'every',
#   'week',
#   'just',
#   'txt',
#   'nokia',
#   'to',
#   'get',
#   'txting',
#   'and',
#   'tell',
#   'ur',
#   'mates',
#   'www',
#   'getzed',
#   'co',
#   'uk',
#   'pobox',
#   'wq',
#   'norm',
#   'tone'],
#  ['we', 'can', 'make', 'baby', 'in', 'yo', 'tho'],
#  ['somebody', 'should', 'go', 'to', 'andros', 'and', 'steal', 'ice'],
#  ['but', 'surprised', 'she', 'still', 'can', 'guess', 'right', 'lor'],
#  ['thank', 'you', 'like', 'you', 'as', 'well'],
#  ['take',
#   'it',
#   'the',
#   'post',
#   'has',
#   'come',
#   'then',
#   'you',
#   'must',
#   'have',
#   'of',
#   'texts',
#   'now',
#   'happy',
#   'reading',
#   'my',
#   'one',
#   'from',
#   'wiv',
#   'hello',
#   'caroline',
#   'at',
#   'the',
#   'end',
#   'is',
#   'my',
#   'favourite',
#   'bless',
#   'him'],
#  ['that', 'we', 'haf', 'to', 'combine', 'how', 'lor'],
#  ['tell',
#   'you',
#   'what',
#   'if',
#   'you',
#   'make',
#   'little',
#   'spreadsheet',
#   'and',
#   'track',
#   'whose',
#   'idea',
#   'it',
#   'was',
#   'to',
#   'smoke',
#   'to',
#   'determine',
#   'who',
#   'smokes',
#   'too',
#   'much',
#   'for',
#   'the',
#   'entire',
#   'month',
#   'of',
#   'february',
#   'll',
#   'come',
#   'up'],
#  ['honeybee',
#   'said',
#   'sweetest',
#   'in',
#   'world',
#   'god',
#   'laughed',
#   'amp',
#   'said',
#   'wait',
#   'havnt',
#   'met',
#   'person',
#   'reading',
#   'this',
#   'msg',
#   'moral',
#   'even',
#   'god',
#   'can',
#   'crack',
#   'jokes',
#   'gm',
#   'gn',
#   'ge',
#   'gn'],
#  ['that',
#   'would',
#   'be',
#   'good',
#   'll',
#   'phone',
#   'you',
#   'tomo',
#   'lunchtime',
#   'shall',
#   'to',
#   'organise',
#   'something'],
#  ['thanks',
#   'da',
#   'thangam',
#   'feel',
#   'very',
#   'very',
#   'happy',
#   'dear',
#   'also',
#   'miss',
#   'you',
#   'da'],
#  ['science',
#   'tells',
#   'that',
#   'chocolate',
#   'will',
#   'melt',
#   'under',
#   'the',
#   'sunlight',
#   'please',
#   'don',
#   'walk',
#   'under',
#   'the',
#   'sunlight',
#   'bcoz',
#   'don',
#   'want',
#   'to',
#   'loss',
#   'sweet',
#   'friend'],
#  ['just', 'taste', 'fish', 'curry'],
#  ['reverse', 'is', 'cheating', 'that', 'is', 'not', 'mathematics'],
#  ['excellent',
#   'spent',
#   'lt',
#   'gt',
#   'years',
#   'in',
#   'the',
#   'air',
#   'force',
#   'iraq',
#   'and',
#   'afghanistan',
#   'am',
#   'stable',
#   'and',
#   'honest',
#   'do',
#   'you',
#   'like',
#   'traveling'],
#  ['hi',
#   'darlin',
#   'finish',
#   'at',
#   'do',
#   'pick',
#   'me',
#   'up',
#   'or',
#   'meet',
#   'me',
#   'text',
#   'back',
#   'on',
#   'this',
#   'number',
#   'luv',
#   'kate',
#   'xxx'],
#  ['dai',
#   'what',
#   'this',
#   'da',
#   'can',
#   'send',
#   'my',
#   'resume',
#   'to',
#   'this',
#   'id'],
#  ['havent', 'add', 'yet', 'right'],
#  ['ok', 'then'],
#  ['say',
#   'this',
#   'slowly',
#   'god',
#   'love',
#   'you',
#   'amp',
#   'need',
#   'you',
#   'clean',
#   'my',
#   'heart',
#   'with',
#   'your',
#   'blood',
#   'send',
#   'this',
#   'to',
#   'ten',
#   'special',
#   'people',
#   'amp',
#   'miracle',
#   'tomorrow',
#   'do',
#   'it',
#   'pls',
#   'pls',
#   'do',
#   'it'],
#  ['hi', 'this', 'is', 'yijue', 'can', 'meet', 'at', 'tmr'],
#  ['good',
#   'afternoon',
#   'babe',
#   'how',
#   'goes',
#   'that',
#   'day',
#   'any',
#   'job',
#   'prospects',
#   'yet',
#   'miss',
#   'you',
#   'my',
#   'love',
#   'sighs'],
#  ['ahhhh',
#   'just',
#   'woken',
#   'up',
#   'had',
#   'bad',
#   'dream',
#   'about',
#   'tho',
#   'so',
#   'dont',
#   'like',
#   'right',
#   'now',
#   'didnt',
#   'know',
#   'anything',
#   'about',
#   'comedy',
#   'night',
#   'but',
#   'guess',
#   'im',
#   'up',
#   'for',
#   'it'],
#  ['she',
#   'said',
#   'do',
#   'mind',
#   'if',
#   'go',
#   'into',
#   'the',
#   'bedroom',
#   'for',
#   'minute',
#   'ok',
#   'sed',
#   'in',
#   'sexy',
#   'mood',
#   'she',
#   'came',
#   'out',
#   'minuts',
#   'latr',
#   'wid',
#   'cake',
#   'my',
#   'wife'],
#  ['we', 'can', 'go', 'normal', 'pilates', 'after', 'our', 'intro'],
#  ['ah',
#   'poop',
#   'looks',
#   'like',
#   'ill',
#   'prob',
#   'have',
#   'to',
#   'send',
#   'in',
#   'my',
#   'laptop',
#   'to',
#   'get',
#   'fixed',
#   'cuz',
#   'it',
#   'has',
#   'gpu',
#   'problem'],
#  ['you', 'have', 'received', 'your', 'mobile', 'content', 'enjoy'],
#  ['hey', 'still', 'online', 've', 'finished', 'the', 'formatting'],
#  ['lol',
#   'your',
#   'right',
#   'what',
#   'diet',
#   'everyday',
#   'cheat',
#   'anyway',
#   'meant',
#   'to',
#   'be',
#   'fatty'],
#  ['ok', 'ill', 'tell', 'the', 'company'],
#  ['private',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'shows',
#   'un',
#   'redeemed',
#   'points',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['damn', 'poor', 'zac', 'doesn', 'stand', 'chance'],
#  ['got', 'your', 'back', 'do', 'you', 'have', 'any', 'dislikes', 'in', 'bed'],
#  ['my',
#   'house',
#   'here',
#   'sky',
#   'quite',
#   'dark',
#   'liao',
#   'if',
#   'raining',
#   'then',
#   'got',
#   'excuse',
#   'not',
#   'run',
#   'already',
#   'rite',
#   'hee'],
#  ['they',
#   'said',
#   'if',
#   'its',
#   'gonna',
#   'snow',
#   'it',
#   'will',
#   'start',
#   'around',
#   'or',
#   'pm',
#   'tonite',
#   'they',
#   'are',
#   'predicting',
#   'an',
#   'inch',
#   'of',
#   'accumulation'],
#  ['once', 'free', 'call', 'me', 'sir', 'am', 'waiting', 'for', 'you'],
#  ['it',
#   'wont',
#   'until',
#   'as',
#   'trying',
#   'sort',
#   'house',
#   'out',
#   'is',
#   'that',
#   'ok'],
#  ['no', 'but', 'we', 'll', 'do', 'medical', 'missions', 'to', 'nigeria'],
#  ['then',
#   'its',
#   'most',
#   'likely',
#   'called',
#   'mittelschmertz',
#   'google',
#   'it',
#   'if',
#   'you',
#   'dont',
#   'have',
#   'paracetamol',
#   'dont',
#   'worry',
#   'it',
#   'will',
#   'go'],
#  ['it',
#   'only',
#   'ard',
# ...
#   'crave',
#   'you',
#   'but',
#   'most',
#   'of',
#   'all',
#   'love',
#   'you',
#   'my',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['at', 'what', 'time', 'should', 'come', 'tomorrow'],
#  ['its',
#   'ur',
#   'luck',
#   'to',
#   'love',
#   'someone',
#   'its',
#   'ur',
#   'fortune',
#   'to',
#   'love',
#   'the',
#   'one',
#   'who',
#   'loves',
#   'but',
#   'its',
#   'miracle',
#   'to',
#   'love',
#   'person',
#   'who',
#   'can',
#   'love',
#   'anyone',
#   'except',
#   'gud',
#   'nyt'],
#  ['mum',
#   'say',
#   'we',
#   'wan',
#   'to',
#   'go',
#   'then',
#   'go',
#   'then',
#   'she',
#   'can',
#   'shun',
#   'bian',
#   'watch',
#   'da',
#   'glass',
#   'exhibition'],
#  ['wud',
#   'never',
#   'mind',
#   'if',
#   'dont',
#   'miss',
#   'me',
#   'or',
#   'if',
#   'dont',
#   'need',
#   'me',
#   'but',
#   'wil',
#   'really',
#   'hurt',
#   'me',
#   'wen',
#   'need',
#   'me',
#   'amp',
#   'dont',
#   'tell',
#   'me',
#   'take',
#   'care'],
#  ['tell', 'me', 'again', 'what', 'your', 'address', 'is'],
#  ['meant',
#   'as',
#   'an',
#   'apology',
#   'from',
#   'me',
#   'for',
#   'texting',
#   'you',
#   'to',
#   'get',
#   'me',
#   'drugs',
#   'at',
#   'lt',
#   'gt',
#   'at',
#   'night'],
#  ['congratulations',
#   'ur',
#   'awarded',
#   'either',
#   'yrs',
#   'supply',
#   'of',
#   'cds',
#   'from',
#   'virgin',
#   'records',
#   'or',
#   'mystery',
#   'gift',
#   'guaranteed',
#   'call',
#   'ts',
#   'cs',
#   'www',
#   'smsco',
#   'net',
#   'pm',
#   'approx',
#   'mins'],
#  ['have',
#   'you',
#   'bookedthe',
#   'hut',
#   'and',
#   'also',
#   'your',
#   'time',
#   'off',
#   'how',
#   'are',
#   'you',
#   'by',
#   'the',
#   'way'],
#  ['try', 'neva', 'mate'],
#  ['yup',
#   'izzit',
#   'still',
#   'raining',
#   'heavily',
#   'cos',
#   'in',
#   'mrt',
#   'can',
#   'outside'],
#  ['yo',
#   'you',
#   'guys',
#   'ever',
#   'figure',
#   'out',
#   'how',
#   'much',
#   'we',
#   'need',
#   'for',
#   'alcohol',
#   'jay',
#   'and',
#   'are',
#   'trying',
#   'to',
#   'figure',
#   'out',
#   'how',
#   'much',
#   'we',
#   'can',
#   'safely',
#   'spend',
#   'on',
#   'weed'],
#  ['sorry', 'll', 'call', 'later'],
#  ['no', 'its', 'true', 'do', 'knw', 'dis', 'no', 'lt', 'gt'],
#  ['eerie',
#   'nokia',
#   'tones',
#   'rply',
#   'tone',
#   'title',
#   'to',
#   'eg',
#   'tone',
#   'dracula',
#   'to',
#   'titles',
#   'ghost',
#   'addamsfa',
#   'munsters',
#   'exorcist',
#   'twilight',
#   'www',
#   'getzed',
#   'co',
#   'uk',
#   'pobox',
#   'wq'],
#  ['had',
#   'the',
#   'money',
#   'issue',
#   'weigh',
#   'me',
#   'down',
#   'but',
#   'thanks',
#   'to',
#   'you',
#   'can',
#   'breathe',
#   'easier',
#   'now',
#   'll',
#   'make',
#   'sure',
#   'you',
#   'dont',
#   'regret',
#   'it',
#   'thanks'],
#  ['urgent',
#   'your',
#   'mobile',
#   'no',
#   'won',
#   'bonus',
#   'caller',
#   'prize',
#   'on',
#   'this',
#   'is',
#   'the',
#   'nd',
#   'attempt',
#   'to',
#   'reach',
#   'you',
#   'call',
#   'asap',
#   'box',
#   'qp',
#   'ppm'],
#  ['sun',
#   'cant',
#   'come',
#   'to',
#   'earth',
#   'but',
#   'send',
#   'luv',
#   'as',
#   'rays',
#   'cloud',
#   'cant',
#   'come',
#   'to',
#   'river',
#   'but',
#   'send',
#   'luv',
#   'as',
#   'rain',
#   'cant',
#   'come',
#   'to',
#   'meet',
#   'but',
#   'can',
#   'send',
#   'my',
#   'care',
#   'as',
#   'msg',
#   'to',
#   'gud',
#   'evng'],
#  ['see',
#   'knew',
#   'giving',
#   'you',
#   'break',
#   'few',
#   'times',
#   'woul',
#   'lead',
#   'to',
#   'you',
#   'always',
#   'wanting',
#   'to',
#   'miss',
#   'curfew',
#   'was',
#   'gonna',
#   'gibe',
#   'you',
#   'til',
#   'one',
#   'but',
#   'midnight',
#   'movie',
#   'is',
#   'not',
#   'gonna',
#   'get',
#   'out',
#   'til',
#   'after',
#   'you',
#   'need',
#   'to',
#   'come',
#   'home',
#   'you',
#   'need',
#   'to',
#   'getsleep',
#   'and',
#   'if',
#   'anything',
#   'you',
#   'need',
#   'to',
#   'studdying',
#   'ear',
#   'training'],
#  ['meeting', 'da', 'ge', 'at', 'nite', 'tmr'],
#  ['hi',
#   'wk',
#   'been',
#   'ok',
#   'on',
#   'hols',
#   'now',
#   'yes',
#   'on',
#   'for',
#   'bit',
#   'of',
#   'run',
#   'forgot',
#   'that',
#   'have',
#   'hairdressers',
#   'appointment',
#   'at',
#   'four',
#   'so',
#   'need',
#   'to',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'does',
#   'that',
#   'cause',
#   'prob',
#   'for'],
#  ['awesome',
#   'plan',
#   'to',
#   'get',
#   'here',
#   'any',
#   'time',
#   'after',
#   'like',
#   'lt',
#   'gt',
#   'll',
#   'text',
#   'you',
#   'details',
#   'in',
#   'wee',
#   'bit'],
#  ['neshanth', 'tel', 'me', 'who'],
#  ['hmmm', 'still', 'we', 'dont', 'have', 'opener'],
#  ['yup', 'ok'],
#  ['dude',
#   'just',
#   'saw',
#   'parked',
#   'car',
#   'with',
#   'its',
#   'sunroof',
#   'popped',
#   'up',
#   'sux'],
#  ['can',
#   'but',
#   'it',
#   'will',
#   'tell',
#   'quite',
#   'long',
#   'cos',
#   'haven',
#   'finish',
#   'my',
#   'film',
#   'yet'],
#  ['tomarrow',
#   'want',
#   'to',
#   'got',
#   'to',
#   'court',
#   'at',
#   'lt',
#   'decimal',
#   'gt',
#   'so',
#   'you',
#   'come',
#   'to',
#   'bus',
#   'stand',
#   'at'],
#  ['ya',
#   'referin',
#   'to',
#   'mei',
#   'ex',
#   'wat',
#   'no',
#   'ah',
#   'waitin',
#   'to',
#   'treat',
#   'somebody',
#   'shld',
#   'rich',
#   'liao',
#   'so',
#   'gd',
#   'den',
#   'dun',
#   'have',
#   'to',
#   'work',
#   'frm',
#   'tmr',
#   'onwards'],
#  ['sounds',
#   'like',
#   'there',
#   'could',
#   'be',
#   'lot',
#   'of',
#   'time',
#   'spent',
#   'in',
#   'that',
#   'chastity',
#   'device',
#   'boy',
#   'grins',
#   'or',
#   'take',
#   'your',
#   'beatings',
#   'like',
#   'good',
#   'dog',
#   'going',
#   'to',
#   'lounge',
#   'in',
#   'nice',
#   'long',
#   'bath',
#   'now'],
#  ['hey',
#   'hun',
#   'onbus',
#   'goin',
#   'meet',
#   'him',
#   'he',
#   'wants',
#   'go',
#   'out',
#   'meal',
#   'but',
#   'donyt',
#   'feel',
#   'like',
#   'it',
#   'cuz',
#   'have',
#   'get',
#   'last',
#   'bus',
#   'home',
#   'but',
#   'hes',
#   'sweet',
#   'latelyxxx'],
#  ['hey',
#   'darlin',
#   'can',
#   'pick',
#   'up',
#   'at',
#   'college',
#   'if',
#   'tell',
#   'me',
#   'wen',
#   'where',
#   'mt',
#   'love',
#   'pete',
#   'xx'],
#  ['want',
#   'new',
#   'video',
#   'phone',
#   'anytime',
#   'any',
#   'network',
#   'mins',
#   'half',
#   'price',
#   'line',
#   'rental',
#   'free',
#   'text',
#   'for',
#   'months',
#   'reply',
#   'or',
#   'call',
#   'for',
#   'free',
#   'delivery'],
#  ['how',
#   'is',
#   'your',
#   'schedule',
#   'next',
#   'week',
#   'am',
#   'out',
#   'of',
#   'town',
#   'this',
#   'weekend'],
#  ['so',
#   'you',
#   'think',
#   'should',
#   'actually',
#   'talk',
#   'to',
#   'him',
#   'not',
#   'call',
#   'his',
#   'boss',
#   'in',
#   'the',
#   'morning',
#   'went',
#   'to',
#   'this',
#   'place',
#   'last',
#   'year',
#   'and',
#   'he',
#   'told',
#   'me',
#   'where',
#   'could',
#   'go',
#   'and',
#   'get',
#   'my',
#   'car',
#   'fixed',
#   'cheaper',
#   'he',
#   'kept',
#   'telling',
#   'me',
#   'today',
#   'how',
#   'much',
#   'he',
#   'hoped',
#   'would',
#   'come',
#   'back',
#   'in',
#   'how',
#   'he',
#   'always',
#   'regretted',
#   'not',
#   'getting',
#   'my',
#   'number',
#   'etc'],
#  [],
#  ['none', 'of', 'that', 'happening', 'til', 'you', 'get', 'here', 'though'],
#  ['tmr',
#   'then',
#   'brin',
#   'lar',
#   'aiya',
#   'later',
#   'come',
#   'lar',
#   'mayb',
#   'neva',
#   'set',
#   'properly',
#   'got',
#   'da',
#   'help',
#   'sheet',
#   'wif'],
#  ['am', 'on', 'my', 'way'],
#  ['dear',
#   'xxxxxxx',
#   've',
#   'been',
#   'invited',
#   'to',
#   'xchat',
#   'this',
#   'is',
#   'our',
#   'final',
#   'attempt',
#   'to',
#   'contact',
#   'txt',
#   'chat',
#   'to',
#   'msgrcvdhg',
#   'suite',
#   'lands',
#   'row',
#   'hl',
#   'ldn',
#   'yrs'],
#  ['genius',
#   'what',
#   'up',
#   'how',
#   'your',
#   'brother',
#   'pls',
#   'send',
#   'his',
#   'number',
#   'to',
#   'my',
#   'skype'],
#  ['fantasy',
#   'football',
#   'is',
#   'back',
#   'on',
#   'your',
#   'tv',
#   'go',
#   'to',
#   'sky',
#   'gamestar',
#   'on',
#   'sky',
#   'active',
#   'and',
#   'play',
#   'dream',
#   'team',
#   'scoring',
#   'starts',
#   'on',
#   'saturday',
#   'so',
#   'register',
#   'now',
#   'sky',
#   'opt',
#   'out',
#   'to'],
#  ['tomarrow', 'final', 'hearing', 'on', 'my', 'laptop', 'case', 'so', 'cant'],
#  ['well',
#   'there',
#   'not',
#   'lot',
#   'of',
#   'things',
#   'happening',
#   'in',
#   'lindsay',
#   'on',
#   'new',
#   'years',
#   'sighs',
#   'some',
#   'bars',
#   'in',
#   'ptbo',
#   'and',
#   'the',
#   'blue',
#   'heron',
#   'has',
#   'something',
#   'going'],
#  ['someone',
#   'has',
#   'contacted',
#   'our',
#   'dating',
#   'service',
#   'and',
#   'entered',
#   'your',
#   'phone',
#   'becausethey',
#   'fancy',
#   'you',
#   'to',
#   'find',
#   'out',
#   'who',
#   'it',
#   'is',
#   'call',
#   'from',
#   'landline',
#   'pobox',
#   'rg'],
#  ['just',
#   'trying',
#   'to',
#   'figure',
#   'out',
#   'when',
#   'suppose',
#   'to',
#   'see',
#   'couple',
#   'different',
#   'people',
#   'this',
#   'week',
#   'we',
#   'said',
#   'we',
#   'get',
#   'together',
#   'but',
#   'didn',
#   'set',
#   'dates'],
#  ['dear',
#   'voucher',
#   'holder',
#   'to',
#   'claim',
#   'this',
#   'weeks',
#   'offer',
#   'at',
#   'you',
#   'pc',
#   'please',
#   'go',
#   'to',
#   'http',
#   'www',
#   'tlp',
#   'co',
#   'uk',
#   'reward',
#   'ts',
#   'cs',
#   'apply'],
#  ['what', 'time', 'should', 'tell', 'my', 'friend', 'to', 'be', 'around'],
#  ['er', 'yep', 'sure', 'props'],
#  ['ya', 'ok', 'then', 'had', 'dinner'],
#  ['when',
#   're',
#   'you',
#   'guys',
#   'getting',
#   'back',
#   'said',
#   'you',
#   'were',
#   'thinking',
#   'about',
#   'not',
#   'staying',
#   'for',
#   'mcr'],
#  ['recpt',
#   'you',
#   'have',
#   'ordered',
#   'ringtone',
#   'your',
#   'order',
#   'is',
#   'being',
#   'processed'],
#  ['hey', 'you', 'can', 'pay', 'with', 'salary', 'de', 'only', 'lt', 'gt'],
#  ['mon',
#   'okie',
#   'lor',
#   'haha',
#   'best',
#   'is',
#   'cheap',
#   'gd',
#   'food',
#   'la',
#   'ex',
#   'oso',
#   'okie',
#   'depends',
#   'on',
#   'whether',
#   'wana',
#   'eat',
#   'western',
#   'or',
#   'chinese',
#   'food',
#   'den',
#   'which',
#   'prefer'],
#  ['can',
#   'make',
#   'it',
#   'up',
#   'there',
#   'squeezed',
#   'lt',
#   'gt',
#   'bucks',
#   'out',
#   'of',
#   'my',
#   'dad'],
#  ['asked', 'you', 'to', 'call', 'him', 'now', 'ok'],
#  ['pls', 'confirm', 'the', 'time', 'to', 'collect', 'the', 'cheque'],
#  ['gudnite', 'tc', 'practice', 'going', 'on'],
#  ['of',
#   'course',
#   'guess',
#   'god',
#   'just',
#   'got',
#   'me',
#   'on',
#   'hold',
#   'right',
#   'now'],
#  ['go', 'fool', 'dont', 'cheat', 'others', 'ok'],
#  ['pa', 'but', 'not', 'selected'],
#  ['no', 'shoot', 'me', 'in', 'the', 'docs', 'waiting', 'room'],
#  ['the',
#   'most',
#   'beautiful',
#   'girl',
#   'ive',
#   'ever',
#   'seen',
#   'my',
#   'baby',
#   'come',
#   'and',
#   'me',
#   'in',
#   'the',
#   'common',
#   'room'],
#  ['babe',
#   'want',
#   'me',
#   'dont',
#   'baby',
#   'im',
#   'nasty',
#   'and',
#   'have',
#   'thing',
#   'filthyguys',
#   'fancy',
#   'rude',
#   'time',
#   'with',
#   'sexy',
#   'bitch',
#   'how',
#   'about',
#   'we',
#   'go',
#   'slo',
#   'hard',
#   'txt',
#   'xxx',
#   'slo',
#   'msgs'],
#  ['borrow', 'ur', 'bag', 'ok'],
#  ['wat', 'da', 'model', 'num', 'of', 'ur', 'phone'],
#  ['am', 'not', 'having', 'her', 'number', 'sir'],
#  ['same', 'to'],
#  ['both', 'shoot', 'big', 'loads', 'so', 'get', 'ready'],
#  ['where', 'at', 'were', 'hungry', 'too'],
#  ['can',
#   'not',
#   'use',
#   'foreign',
#   'stamps',
#   'in',
#   'this',
#   'country',
#   'good',
#   'lecture'],
#  ['okey',
#   'doke',
#   'at',
#   'home',
#   'but',
#   'not',
#   'dressed',
#   'cos',
#   'laying',
#   'around',
#   'ill',
#   'speak',
#   'to',
#   'you',
#   'later',
#   'bout',
#   'times',
#   'and',
#   'stuff'],
#  ['is', 'there', 'any', 'training', 'tomorrow'],
#  ['where', 'can', 'download', 'clear', 'movies', 'dvd', 'copies'],
#  ['we',
#   'regret',
#   'to',
#   'inform',
#   'that',
#   'the',
#   'nhs',
#   'has',
#   'made',
#   'mistake',
#   'were',
#   'never',
#   'actually',
#   'born',
#   'please',
#   'report',
#   'yor',
#   'local',
#   'hospital',
#   'terminated',
#   'we',
#   'sorry',
#   'the',
#   'inconvenience'],
#  ['what',
#   'do',
#   'want',
#   'when',
#   'come',
#   'back',
#   'beautiful',
#   'necklace',
#   'as',
#   'token',
#   'of',
#   'my',
#   'heart',
#   'for',
#   'you',
#   'thats',
#   'what',
#   'will',
#   'give',
#   'but',
#   'only',
#   'to',
#   'my',
#   'wife',
#   'of',
#   'my',
#   'liking',
#   'be',
#   'that',
#   'and',
#   'see',
#   'no',
#   'one',
#   'can',
#   'give',
#   'you',
#   'that',
#   'dont',
#   'call',
#   'me',
#   'will',
#   'wait',
#   'till',
#   'come'],
#  ['realise',
#   'you',
#   'are',
#   'busy',
#   'guy',
#   'and',
#   'trying',
#   'not',
#   'to',
#   'be',
#   'bother',
#   'have',
#   'to',
#   'get',
#   'some',
#   'exams',
#   'outta',
#   'the',
#   'way',
#   'and',
#   'then',
#   'try',
#   'the',
#   'cars',
#   'do',
#   'have',
#   'gr',
#   'day'],
#  ['bit',
#   'of',
#   'ur',
#   'smile',
#   'is',
#   'my',
#   'hppnss',
#   'drop',
#   'of',
#   'ur',
#   'tear',
#   'is',
#   'my',
#   'sorrow',
#   'part',
#   'of',
#   'ur',
#   'heart',
#   'is',
#   'my',
#   'life',
#   'heart',
#   'like',
#   'mine',
#   'wil',
#   'care',
#   'for',
#   'forevr',
#   'as',
#   'my',
#   'goodfriend'],
#  ['if', 'you', 'are', 'not', 'coughing', 'then', 'its', 'nothing'],
#  ['sorry', 'in', 'meeting', 'll', 'call', 'later'],
#  ['great', 'so', 'should', 'send', 'you', 'my', 'account', 'number'],
#  ['you', 'want', 'to', 'go'],
#  ['depends',
#   'on',
#   'quality',
#   'if',
#   'you',
#   'want',
#   'the',
#   'type',
#   'sent',
#   'boye',
#   'faded',
#   'glory',
#   'then',
#   'about',
#   'if',
#   'you',
#   'want',
#   'ralphs',
#   'maybe'],
#  ['mm',
#   'feeling',
#   'sleepy',
#   'today',
#   'itself',
#   'shall',
#   'get',
#   'that',
#   'dear'],
#  ['freemsg',
#   'why',
#   'haven',
#   'you',
#   'replied',
#   'to',
#   'my',
#   'text',
#   'randy',
#   'sexy',
#   'female',
#   'and',
#   'live',
#   'local',
#   'luv',
#   'to',
#   'hear',
#   'from',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'to',
#   'end'],
#  ['at',
#   'the',
#   'latest',
#   'still',
#   'there',
#   'if',
#   'you',
#   'can',
#   'scrounge',
#   'up',
#   'some',
#   'ammo',
#   'and',
#   'want',
#   'to',
#   'give',
#   'the',
#   'new',
#   'ak',
#   'try'],
#  ['onum', 'ela', 'pa', 'normal', 'than'],
#  ['thanx',
#   'darlin',
#   'im',
#   'cool',
#   'thanx',
#   'few',
#   'bday',
#   'drinks',
#   'nite',
#   'morrow',
#   'off',
#   'take',
#   'care',
#   'soon',
#   'xxx'],
#  ['no',
#   'promises',
#   'on',
#   'when',
#   'though',
#   'haven',
#   'even',
#   'gotten',
#   'dinner',
#   'yet'],
#  ['sos', 'any', 'amount', 'can', 'get', 'pls'],
#  ['ok', 'finishing', 'soon'],
#  ['no', 'message', 'no', 'responce', 'what', 'happend'],
#  ['dude',
#   'what',
#   'up',
#   'how',
#   'teresa',
#   'hope',
#   'you',
#   'have',
#   'been',
#   'okay',
#   'when',
#   'didnt',
#   'hear',
#   'from',
#   'these',
#   'people',
#   'called',
#   'them',
#   'and',
#   'they',
#   'had',
#   'received',
#   'the',
#   'package',
#   'since',
#   'dec',
#   'lt',
#   'gt',
#   'just',
#   'thot',
#   'you',
#   'ld',
#   'like',
#   'to',
#   'know',
#   'do',
#   'have',
#   'fantastic',
#   'year',
#   'and',
#   'all',
#   'the',
#   'best',
#   'with',
#   'your',
#   'reading',
#   'plus',
#   'if',
#   'you',
#   'can',
#   'really',
#   'really',
#   'bam',
#   'first',
#   'aid',
#   'for',
#   'usmle',
#   'then',
#   'your',
#   'work',
#   'is',
#   'done'],
#  ['house',
#   'maid',
#   'is',
#   'the',
#   'murderer',
#   'coz',
#   'the',
#   'man',
#   'was',
#   'murdered',
#   'on',
#   'lt',
#   'gt',
#   'th',
#   'january',
#   'as',
#   'public',
#   'holiday',
#   'all',
#   'govt',
#   'instituitions',
#   'are',
#   'closed',
#   'including',
#   'post',
#   'office',
#   'understand'],
#  ['well',
#   'keep',
#   'in',
#   'mind',
#   've',
#   'only',
#   'got',
#   'enough',
#   'gas',
#   'for',
#   'one',
#   'more',
#   'round',
#   'trip',
#   'barring',
#   'sudden',
#   'influx',
#   'of',
#   'cash'],
#  ['loosu', 'go', 'to', 'hospital', 'de', 'dont', 'let', 'it', 'careless'],
#  ['so', 'dont', 'use', 'hook', 'up', 'any', 'how'],
#  ['private',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'shows',
#   'unredeemed',
#   'bonus',
#   'points',
#   'to',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['what', 'will', 'we', 'do', 'in', 'the', 'shower', 'baby'],
#  ['fine', 'anytime', 'all', 'the', 'best', 'with', 'it'],
#  ['so',
#   'many',
#   'people',
#   'seems',
#   'to',
#   'be',
#   'special',
#   'at',
#   'first',
#   'sight',
#   'but',
#   'only',
#   'very',
#   'few',
#   'will',
#   'remain',
#   'special',
#   'to',
#   'you',
#   'till',
#   'your',
#   'last',
#   'sight',
#   'maintain',
#   'them',
#   'till',
#   'life',
#   'ends',
#   'sh',
#   'jas'],
#  ['good',
#   'afternoon',
#   'my',
#   'love',
#   'any',
#   'job',
#   'prospects',
#   'are',
#   'you',
#   'missing',
#   'me',
#   'what',
#   'do',
#   'you',
#   'do',
#   'are',
#   'you',
#   'being',
#   'lazy',
#   'and',
#   'bleak',
#   'hmmm',
#   'or',
#   'happy',
#   'and',
#   'filled',
#   'with',
#   'my',
#   'love'],
#  ['then', 'drive', 'lor'],
#  ['life',
#   'is',
#   'nothing',
#   'wen',
#   'get',
#   'everything',
#   'but',
#   'life',
#   'is',
#   'everything',
#   'wen',
#   'miss',
#   'something',
#   'real',
#   'value',
#   'of',
#   'people',
#   'wil',
#   'be',
#   'realized',
#   'only',
#   'in',
#   'their',
#   'absence',
#   'gud',
#   'mrng'],
#  ['where',
#   'at',
#   'dogbreath',
#   'its',
#   'just',
#   'sounding',
#   'like',
#   'jan',
#   'that',
#   'al'],
#  ...]

# %% [markdown]
# ## Applying Word2Vec for training set

# %%
x_train_vect = []
temp1=[]

#print(len(X_train))
for ls in x_train:
    for i in ls:
        if i in words:
            temp1.append(np.array(w2v_model.wv[i]))
    x_train_vect.append(np.mean(np.array(temp1), axis = 0))

# %%
x_train_vect = np.array(x_train_vect)
x_train_vect.shape
# Out:
# (4457, 100)

# %% [markdown]
# ## Applying Word2Vec for Test Set

# %%
x_test_vect = []
temp1=[]

for ls in x_test:
    for i in ls:
        if i in words:
            temp1.append(np.array(w2v_model.wv[i]))
    x_test_vect.append(np.mean(np.array(temp1), axis = 0))

# %%
x_test_vect = np.array(x_test_vect)
x_test_vect.shape
# Out:
# (1115, 100)

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc_classifier = rfc.fit(x_train_vect, y_train)

# %% [markdown]
# ### Accuracy for Training Set

# %%
y_pred = rfc_classifier.predict(x_train_vect)

# %%
from sklearn.metrics import precision_score, recall_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
accuracy = (y_pred==y_train).sum()/len(y_pred)

precision = precision_score(y_train, y_pred, pos_label='ham')
recall = recall_score(y_train, y_pred, pos_label='ham')

print('Accuracy: {} , Precision: {} , Recall: {}'.format(accuracy, precision, recall))
print(classification_report(y_train, y_pred))
print(confusion_matrix(y_train, y_pred))
# Out:
# Accuracy: 0.9991025353376711 , Precision: 0.9989645353352317 , Recall: 1.0
#               precision    recall  f1-score   support
#
#          ham       1.00      1.00      1.00      3859
#         spam       1.00      0.99      1.00       598
#
#     accuracy                           1.00      4457
#    macro avg       1.00      1.00      1.00      4457
# weighted avg       1.00      1.00      1.00      4457
#
# [[3859    0]
#  [   4  594]]

# %% [markdown]
# ### Accuracy for Test Set

# %%
y_pred = rfc_classifier.predict(x_test_vect)

# %%
precision = precision_score(y_test, y_pred, pos_label='ham')
recall = recall_score(y_test, y_pred, pos_label='ham')
accuracy = (y_pred==y_test).sum()/len(y_pred)

print('Accuracy: {} , Precision: {} , Recall: {}'.format(accuracy, precision, recall))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.8663677130044843 , Precision: 0.8663677130044843 , Recall: 1.0
#               precision    recall  f1-score   support
#
#          ham       0.87      1.00      0.93       966
#         spam       0.00      0.00      0.00       149
#
#     accuracy                           0.87      1115
#    macro avg       0.43      0.50      0.46      1115
# weighted avg       0.75      0.87      0.80      1115
#
# [[966   0]
#  [149   0]]
# C:\Users\yatha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\yatha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\yatha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
spam_detect_model = LogisticRegression().fit(x_train_vect, y_train)

# %% [markdown]
# ### Predicting for Training Set

# %%
y_pred = spam_detect_model.predict(x_train_vect)

# %%
from sklearn.metrics import accuracy_score,classification_report
score=accuracy_score(y_train,y_pred)
print(score)
# Out:
# 0.8658290329818263

# %% [markdown]
# ### Predicting for Test Set

# %%
y_pred = spam_detect_model.predict(x_test_vect)

# %%
score=accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.8663677130044843
